# %%
from astropy.io import ascii
from astropy.table import Table, Column, Row
import matplotlib.pyplot as plt
from __future__ import division
import numpy as np
import pandas as pd
import scipy as scipy
import matplotlib.patches as mpatches
from scipy.stats import maxwell
from scipy import stats
from scipy.stats import norm
import matplotlib.gridspec as gridspec
import math
# %matplotlib inline

# %%
#Reading the data
data_1851 = ascii.read("BSS_velocity_mass_1851.txt")
data_3201 = ascii.read("BSS_velocity_mass_3201.txt")
data_4590 = ascii.read("BSS_velocity_mass_4590.txt")
data_4833 = ascii.read("BSS_velocity_mass_4833.txt")
data_5286 = ascii.read("BSS_velocity_mass_5286.txt")
data_5927 = ascii.read("BSS_velocity_mass_5927.txt")
data_6101 = ascii.read("BSS_velocity_mass_6101.txt")
data_6121 = ascii.read("BSS_velocity_mass_6121.txt")
data_6171 = ascii.read("BSS_velocity_mass_6171.txt")
data_6218 = ascii.read("BSS_velocity_mass_6218.txt")
data_6254 = ascii.read("BSS_velocity_mass_6254.txt")
data_6304 = ascii.read("BSS_velocity_mass_6304.txt")
data_6341 = ascii.read("BSS_velocity_mass_6341.txt")
data_6352 = ascii.read("BSS_velocity_mass_6352.txt")
data_6362 = ascii.read("BSS_velocity_mass_6362.txt")
data_6366 = ascii.read("BSS_velocity_mass_6366.txt")
data_6388 = ascii.read("BSS_velocity_mass_6388.txt")
data_6541 = ascii.read("BSS_velocity_mass_6541.txt")
data_6584 = ascii.read("BSS_velocity_mass_6584.txt")
data_6624 = ascii.read("BSS_velocity_mass_6624.txt")
data_6637 = ascii.read("BSS_velocity_mass_6637.txt")
data_6652 = ascii.read("BSS_velocity_mass_6652.txt")
data_6656 = ascii.read("BSS_velocity_mass_6656.txt")
data_6681 = ascii.read("BSS_velocity_mass_6681.txt")
data_6717 = ascii.read("BSS_velocity_mass_6717.txt")
data_6723 = ascii.read("BSS_velocity_mass_6723.txt")
data_6809 = ascii.read("BSS_velocity_mass_6809.txt")
data_6838 = ascii.read("BSS_velocity_mass_3201.txt")
data_7089 = ascii.read("BSS_velocity_mass_7089.txt")
data_7099 = ascii.read("BSS_velocity_mass_7099.txt")

# %%
#Making them into arrays

v_1851 = np.asarray(data_1851['velocity(km/s)'])
m_1851 = np.asarray(data_1851['mass(Msun)'])

v_3201 = np.asarray(data_3201['velocity(km/s)'])
m_3201 = np.asarray(data_3201['mass(Msun)'])

v_4590 = np.asarray(data_4590['col1'])
m_4590 = np.asarray(data_4590['col2'])

v_4833 = np.asarray(data_4833['col1'])
m_4833 = np.asarray(data_4833['col2'])

v_5286 = np.asarray(data_5286['col1'])
m_5286 = np.asarray(data_5286['col2'])

v_5927 = np.asarray(data_5927['col1'])
m_5927 = np.asarray(data_5927['col2'])

v_6101 = np.asarray(data_6101['col1'])
m_6101 = np.asarray(data_6101['col2'])

v_6121 = np.asarray(data_6121['col1'])
m_6121 = np.asarray(data_6121['col2'])

v_6171 = np.asarray(data_6171['col1'])
m_6171 = np.asarray(data_6171['col2'])

v_6218 = np.asarray(data_6218['col1'])
m_6218 = np.asarray(data_6218['col2'])

v_6254 = np.asarray(data_6254['col1'])
m_6254 = np.asarray(data_6254['col2'])

v_6304 = np.asarray(data_6304['col1'])
m_6304 = np.asarray(data_6304['col2'])

v_6341 = np.asarray(data_6341['col1'])
m_6341 = np.asarray(data_6341['col2'])

v_6352 = np.asarray(data_6352['col1'])
m_6352 = np.asarray(data_6352['col2'])

v_6362 = np.asarray(data_6362['col1'])
m_6362 = np.asarray(data_6362['col2'])

v_6366 = np.asarray(data_6366['col1'])
m_6366 = np.asarray(data_6366['col2'])

v_6388 = np.asarray(data_6388['col1'])
m_6388 = np.asarray(data_6388['col2'])

v_6541 = np.asarray(data_6541['col1'])
m_6541 = np.asarray(data_6541['col2'])

v_6584 = np.asarray(data_6584['col1'])
m_6584 = np.asarray(data_6584['col2'])

v_6624 = np.asarray(data_6624['col1'])
m_6624 = np.asarray(data_6624['col2'])

v_6637 = np.asarray(data_6637['col1'])
m_6637 = np.asarray(data_6637['col2'])

v_6652 = np.asarray(data_6652['col1'])
m_6652 = np.asarray(data_6652['col2'])

v_6656 = np.asarray(data_6656['col1'])
m_6656 = np.asarray(data_6656['col2'])

v_6681 = np.asarray(data_6681['col1'])
m_6681 = np.asarray(data_6681['col2'])

v_6717 = np.asarray(data_6717['col1'])
m_6717 = np.asarray(data_6717['col2'])

v_6723 = np.asarray(data_6723['col1'])
m_6723 = np.asarray(data_6723['col2'])

v_6809 = np.asarray(data_6809['col1'])
m_6809 = np.asarray(data_6809['col2'])

v_6838 = np.asarray(data_6838['velocity(km/s)'])
m_6838 = np.asarray(data_6838['mass(Msun)'])

v_7089 = np.asarray(data_7089['col1'])
m_7089 = np.asarray(data_7089['col2'])

v_7099 = np.asarray(data_7099['col1'])
m_7099 = np.asarray(data_7099['col2'])

# %%
#Use pandas to read theoretical data

#1851 num 1 doesnt work
data_1851_num2 = pd.read_csv('mb_NGC1851_ecnum2.txt',sep=" ") 
data_1851_num2_ind = data_1851_num2[2:] 

data_3201_num1 = pd.read_csv('mb_NGC3201_ecnum1.txt',sep=" ") 
data_3201_num1_ind = data_3201_num1[2:] 
data_3201_num2 = pd.read_csv('mb_NGC3201_ecnum2.txt',sep=" ") 
data_3201_num2_ind = data_3201_num2[2:]

data_4590_num1 = pd.read_csv('mb_NGC4590_ecnum1.txt',sep=" ") 
data_4590_num1_ind = data_4590_num1[2:] 
data_4590_num2 = pd.read_csv('mb_NGC4590_ecnum2.txt',sep=" ") 
data_4590_num2_ind = data_4590_num2[2:]

data_4833_num1 = pd.read_csv('mb_NGC4833_ecnum1.txt',sep=" ") 
data_4833_num1_ind = data_4833_num1[2:] 
data_4833_num2 = pd.read_csv('mb_NGC4833_ecnum2.txt',sep=" ") 
data_4833_num2_ind = data_4833_num2[2:]

data_5024_num1 = pd.read_csv('mb_NGC5024_ecnum1.txt',sep=" ") 
data_5024_num1_ind = data_5024_num1[2:] 
data_5024_num2 = pd.read_csv('mb_NGC5024_ecnum2.txt',sep=" ") 
data_5024_num2_ind = data_5024_num2[2:]

data_5053_num1 = pd.read_csv('mb_NGC5053_ecnum1.txt',sep=" ") 
data_5053_num1_ind = data_5053_num1[2:] 
data_5053_num2 = pd.read_csv('mb_NGC5053_ecnum2.txt',sep=" ") 
data_5053_num2_ind = data_5053_num2[2:]

data_5286_num1 = pd.read_csv('mb_NGC5286_ecnum1.txt',sep=" ") 
data_5286_num1_ind = data_5286_num1[2:] 
data_5286_num2 = pd.read_csv('mb_NGC5286_ecnum2.txt',sep=" ") 
data_5286_num2_ind = data_5286_num2[2:]

data_5466_num1 = pd.read_csv('mb_NGC5466_ecnum1.txt',sep=" ") 
data_5466_num1_ind = data_5466_num1[2:] 
data_5466_num2 = pd.read_csv('mb_NGC5466_ecnum2.txt',sep=" ") 
data_5466_num2_ind = data_5466_num2[2:]

data_5927_num1 = pd.read_csv('mb_NGC5927_ecnum1.txt',sep=" ") 
data_5927_num1_ind = data_5927_num1[2:] 
data_5927_num2 = pd.read_csv('mb_NGC5927_ecnum2.txt',sep=" ") 
data_5927_num2_ind = data_5927_num2[2:]

data_6101_num1 = pd.read_csv('mb_NGC6101_ecnum1.txt',sep=" ") 
data_6101_num1_ind = data_6101_num1[2:] 
data_6101_num2 = pd.read_csv('mb_NGC6101_ecnum2.txt',sep=" ") 
data_6101_num2_ind = data_6101_num2[2:]

data_6121_num1 = pd.read_csv('mb_NGC6121_ecnum1.txt',sep=" ") 
data_6121_num1_ind = data_6121_num1[2:] 
data_6121_num2 = pd.read_csv('mb_NGC6121_ecnum2.txt',sep=" ") 
data_6121_num2_ind = data_6121_num2[2:]

data_6144_num1 = pd.read_csv('mb_NGC6144_ecnum1.txt',sep=" ") 
data_6144_num1_ind = data_6144_num1[2:] 
data_6144_num2 = pd.read_csv('mb_NGC6144_ecnum2.txt',sep=" ") 
data_6144_num2_ind = data_6144_num2[2:]

data_6171_num1 = pd.read_csv('mb_NGC6171_ecnum1.txt',sep=" ") 
data_6171_num1_ind = data_6171_num1[2:] 
data_6171_num2 = pd.read_csv('mb_NGC6171_ecnum2.txt',sep=" ") 
data_6171_num2_ind = data_6171_num2[2:]

data_6218_num1 = pd.read_csv('mb_NGC6218_ecnum1.txt',sep=" ") 
data_6218_num1_ind = data_6218_num1[2:] 
data_6218_num2 = pd.read_csv('mb_NGC6218_ecnum2.txt',sep=" ") 
data_6218_num2_ind = data_6218_num2[2:]

data_6254_num1 = pd.read_csv('mb_NGC6254_ecnum1.txt',sep=" ") 
data_6254_num1_ind = data_6254_num1[2:] 
data_6254_num2 = pd.read_csv('mb_NGC6254_ecnum2.txt',sep=" ") 
data_6254_num2_ind = data_6254_num2[2:]

data_6304_num1 = pd.read_csv('mb_NGC6304_ecnum1.txt',sep=" ") 
data_6304_num1_ind = data_6304_num1[2:] 
data_6304_num2 = pd.read_csv('mb_NGC6304_ecnum2.txt',sep=" ") 
data_6304_num2_ind = data_6304_num2[2:]

data_6341_num1 = pd.read_csv('mb_NGC6341_ecnum1.txt',sep=" ") 
data_6341_num1_ind = data_6341_num1[2:] 
data_6341_num2 = pd.read_csv('mb_NGC6341_ecnum2.txt',sep=" ") 
data_6341_num2_ind = data_6341_num2[2:]

data_6352_num1 = pd.read_csv('mb_NGC6352_ecnum1.txt',sep=" ") 
data_6352_num1_ind = data_6352_num1[2:] 
data_6352_num2 = pd.read_csv('mb_NGC6352_ecnum2.txt',sep=" ") 
data_6352_num2_ind = data_6352_num2[2:]

data_6362_num1 = pd.read_csv('mb_NGC6362_ecnum1.txt',sep=" ") 
data_6362_num1_ind = data_6362_num1[2:] 
data_6362_num2 = pd.read_csv('mb_NGC6362_ecnum2.txt',sep=" ") 
data_6362_num2_ind = data_6362_num2[2:]

data_6366_num1 = pd.read_csv('mb_NGC6366_ecnum1.txt',sep=" ") 
data_6366_num1_ind = data_6366_num1[2:] 
data_6366_num2 = pd.read_csv('mb_NGC6366_ecnum2.txt',sep=" ") 
data_6366_num2_ind = data_6366_num2[2:]

data_6388_num1 = pd.read_csv('mb_NGC6388_ecnum1.txt',sep=" ") 
data_6388_num1_ind = data_6388_num1[2:] 
data_6388_num2 = pd.read_csv('mb_NGC6388_ecnum2.txt',sep=" ") 
data_6388_num2_ind = data_6388_num2[2:]

data_6535_num1 = pd.read_csv('mb_NGC6535_ecnum1.txt',sep=" ") 
data_6535_num1_ind = data_6535_num1[2:] 
data_6535_num2 = pd.read_csv('mb_NGC6535_ecnum2.txt',sep=" ") 
data_6535_num2_ind = data_6535_num2[2:]

data_6541_num1 = pd.read_csv('mb_NGC6541_ecnum1.txt',sep=" ") 
data_6541_num1_ind = data_6541_num1[2:] 
data_6541_num2 = pd.read_csv('mb_NGC6541_ecnum2.txt',sep=" ") 
data_6541_num2_ind = data_6541_num2[2:]

data_6584_num1 = pd.read_csv('mb_NGC6584_ecnum1.txt',sep=" ") 
data_6584_num1_ind = data_6584_num1[2:] 
data_6584_num2 = pd.read_csv('mb_NGC6584_ecnum2.txt',sep=" ") 
data_6584_num2_ind = data_6584_num2[2:]

data_6541_num1 = pd.read_csv('mb_NGC6541_ecnum1.txt',sep=" ") 
data_6541_num1_ind = data_6541_num1[2:] 
data_6541_num2 = pd.read_csv('mb_NGC6541_ecnum2.txt',sep=" ") 
data_6541_num2_ind = data_6541_num2[2:]

data_6584_num1 = pd.read_csv('mb_NGC6584_ecnum1.txt',sep=" ") 
data_6584_num1_ind = data_6584_num1[2:] 
data_6584_num2 = pd.read_csv('mb_NGC6584_ecnum2.txt',sep=" ") 
data_6584_num2_ind = data_6584_num2[2:]

data_6624_num1 = pd.read_csv('mb_NGC6624_ecnum1.txt',sep=" ") 
data_6624_num1_ind = data_6624_num1[2:] 
data_6624_num2 = pd.read_csv('mb_NGC6624_ecnum2.txt',sep=" ") 
data_6624_num2_ind = data_6624_num2[2:]

data_6637_num1 = pd.read_csv('mb_NGC6637_ecnum1.txt',sep=" ") 
data_6637_num1_ind = data_6637_num1[2:] 
data_6637_num2 = pd.read_csv('mb_NGC6637_ecnum2.txt',sep=" ") 
data_6637_num2_ind = data_6637_num2[2:]

data_6652_num1 = pd.read_csv('mb_NGC6652_ecnum1.txt',sep=" ") 
data_6652_num1_ind = data_6652_num1[2:] 
data_6652_num2 = pd.read_csv('mb_NGC6652_ecnum2.txt',sep=" ") 
data_6652_num2_ind = data_6652_num2[2:]

data_6656_num1 = pd.read_csv('mb_NGC6656_ecnum1.txt',sep=" ") 
data_6656_num1_ind = data_6656_num1[2:] 
data_6656_num2 = pd.read_csv('mb_NGC6656_ecnum2.txt',sep=" ") 
data_6656_num2_ind = data_6656_num2[2:]

data_6681_num1 = pd.read_csv('mb_NGC6681_ecnum1.txt',sep=" ") 
data_6681_num1_ind = data_6681_num1[2:] 
data_6681_num2 = pd.read_csv('mb_NGC6681_ecnum2.txt',sep=" ") 
data_6681_num2_ind = data_6681_num2[2:]

data_6717_num1 = pd.read_csv('mb_NGC6717_ecnum1.txt',sep=" ") 
data_6717_num1_ind = data_6717_num1[2:] 
data_6717_num2 = pd.read_csv('mb_NGC6717_ecnum2.txt',sep=" ") 
data_6717_num2_ind = data_6717_num2[2:]

data_6723_num1 = pd.read_csv('mb_NGC6723_ecnum1.txt',sep=" ") 
data_6723_num1_ind = data_6723_num1[2:] 
data_6723_num2 = pd.read_csv('mb_NGC6723_ecnum2.txt',sep=" ") 
data_6723_num2_ind = data_6723_num2[2:]

data_6809_num1 = pd.read_csv('mb_NGC6809_ecnum1.txt',sep=" ") 
data_6809_num1_ind = data_6809_num1[2:] 
data_6809_num2 = pd.read_csv('mb_NGC6809_ecnum2.txt',sep=" ") 
data_6809_num2_ind = data_6809_num2[2:]

data_6838_num1 = pd.read_csv('mb_NGC6838_ecnum1.txt',sep=" ") 
data_6838_num1_ind = data_6838_num1[2:] 
data_6838_num2 = pd.read_csv('mb_NGC6838_ecnum2.txt',sep=" ") 
data_6838_num2_ind = data_6838_num2[2:]

data_6934_num1 = pd.read_csv('mb_NGC6934_ecnum1.txt',sep=" ") 
data_6934_num1_ind = data_6934_num1[2:] 
data_6934_num2 = pd.read_csv('mb_NGC6934_ecnum2.txt',sep=" ") 
data_6934_num2_ind = data_6934_num2[2:]

data_6981_num1 = pd.read_csv('mb_NGC6981_ecnum1.txt',sep=" ") 
data_6981_num1_ind = data_6981_num1[2:] 
data_6981_num2 = pd.read_csv('mb_NGC6981_ecnum2.txt',sep=" ") 
data_6981_num2_ind = data_6981_num2[2:]

data_7089_num1 = pd.read_csv('mb_NGC7089_ecnum1.txt',sep=" ") 
data_7089_num1_ind = data_7089_num1[2:] 
data_7089_num2 = pd.read_csv('mb_NGC7089_ecnum2.txt',sep=" ") 
data_7089_num2_ind = data_7089_num2[2:]

data_7099_num1 = pd.read_csv('mb_NGC7099_ecnum1.txt',sep=" ") 
data_7099_num1_ind = data_7099_num1[2:] 
data_7099_num2 = pd.read_csv('mb_NGC7099_ecnum2.txt',sep=" ") 
data_7099_num2_ind = data_7099_num2[2:]
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Making table into arrays

m_1851_num2 = np.array(data_1851_num2_ind['#Mcl[MSun]'])
v_1851_num2 = np.array(data_1851_num2_ind['Unnamed: 1'])

m_3201_num1 = np.array(data_3201_num1_ind['#Mcl[MSun]'])
v_3201_num1 = np.array(data_3201_num1_ind['Unnamed: 1'])
m_3201_num2 = np.array(data_3201_num2_ind['#Mcl[MSun]'])
v_3201_num2 = np.array(data_3201_num2_ind['Unnamed: 1'])

m_4590_num1 = np.array(data_4590_num1_ind['#Mcl[MSun]'])
v_4590_num1 = np.array(data_4590_num1_ind['Unnamed: 1'])
m_4590_num2 = np.array(data_4590_num2_ind['#Mcl[MSun]'])
v_4590_num2 = np.array(data_4590_num2_ind['Unnamed: 1'])

m_4833_num1 = np.array(data_4833_num1_ind['#Mcl[MSun]'])
v_4833_num1 = np.array(data_4833_num1_ind['Unnamed: 1'])
m_4833_num2 = np.array(data_4833_num2_ind['#Mcl[MSun]'])
v_4833_num2 = np.array(data_4833_num2_ind['Unnamed: 1'])

m_5024_num1 = np.array(data_5024_num1_ind['#Mcl[MSun]'])
v_5024_num1 = np.array(data_5024_num1_ind['Unnamed: 1'])
m_5024_num2 = np.array(data_5024_num2_ind['#Mcl[MSun]'])
v_5024_num2 = np.array(data_5024_num2_ind['Unnamed: 1'])

m_5053_num1 = np.array(data_5053_num1_ind['#Mcl[MSun]'])
v_5053_num1 = np.array(data_5053_num1_ind['Unnamed: 1'])
m_5053_num2 = np.array(data_5053_num2_ind['#Mcl[MSun]'])
v_5053_num2 = np.array(data_5053_num2_ind['Unnamed: 1'])

m_5286_num1 = np.array(data_5286_num1_ind['#Mcl[MSun]'])
v_5286_num1 = np.array(data_5286_num1_ind['Unnamed: 1'])
m_5286_num2 = np.array(data_5286_num2_ind['#Mcl[MSun]'])
v_5286_num2 = np.array(data_5286_num2_ind['Unnamed: 1'])

m_5466_num1 = np.array(data_5466_num1_ind['#Mcl[MSun]'])
v_5466_num1 = np.array(data_5466_num1_ind['Unnamed: 1'])
m_5466_num2 = np.array(data_5466_num2_ind['#Mcl[MSun]'])
v_5466_num2 = np.array(data_5466_num2_ind['Unnamed: 1'])

m_5927_num1 = np.array(data_5927_num1_ind['#Mcl[MSun]'])
v_5927_num1 = np.array(data_5927_num1_ind['Unnamed: 1'])
m_5927_num2 = np.array(data_5927_num2_ind['#Mcl[MSun]'])
v_5927_num2 = np.array(data_5927_num2_ind['Unnamed: 1'])

m_6101_num1 = np.array(data_6101_num1_ind['#Mcl[MSun]'])
v_6101_num1 = np.array(data_6101_num1_ind['Unnamed: 1'])
m_6101_num2 = np.array(data_6101_num2_ind['#Mcl[MSun]'])
v_6101_num2 = np.array(data_6101_num2_ind['Unnamed: 1'])

m_6121_num1 = np.array(data_6121_num1_ind['#Mcl[MSun]'])
v_6121_num1 = np.array(data_6121_num1_ind['Unnamed: 1'])
m_6121_num2 = np.array(data_6121_num2_ind['#Mcl[MSun]'])
v_6121_num2 = np.array(data_6121_num2_ind['Unnamed: 1'])

m_6144_num1 = np.array(data_6144_num1_ind['#Mcl[MSun]'])
v_6144_num1 = np.array(data_6144_num1_ind['Unnamed: 1'])
m_6144_num2 = np.array(data_6144_num2_ind['#Mcl[MSun]'])
v_6144_num2 = np.array(data_6144_num2_ind['Unnamed: 1'])

m_6171_num1 = np.array(data_6171_num1_ind['#Mcl[MSun]'])
v_6171_num1 = np.array(data_6171_num1_ind['Unnamed: 1'])
m_6171_num2 = np.array(data_6171_num2_ind['#Mcl[MSun]'])
v_6171_num2 = np.array(data_6171_num2_ind['Unnamed: 1'])

m_6218_num1 = np.array(data_6218_num1_ind['#Mcl[MSun]'])
v_6218_num1 = np.array(data_6218_num1_ind['Unnamed: 1'])
m_6218_num2 = np.array(data_6218_num2_ind['#Mcl[MSun]'])
v_6218_num2 = np.array(data_6218_num2_ind['Unnamed: 1'])

m_6254_num1 = np.array(data_6254_num1_ind['#Mcl[MSun]'])
v_6254_num1 = np.array(data_6254_num1_ind['Unnamed: 1'])
m_6254_num2 = np.array(data_6254_num2_ind['#Mcl[MSun]'])
v_6254_num2 = np.array(data_6254_num2_ind['Unnamed: 1'])

m_6304_num1 = np.array(data_6304_num1_ind['#Mcl[MSun]'])
v_6304_num1 = np.array(data_6304_num1_ind['Unnamed: 1'])
m_6304_num2 = np.array(data_6304_num2_ind['#Mcl[MSun]'])
v_6304_num2 = np.array(data_6304_num2_ind['Unnamed: 1'])

m_6341_num1 = np.array(data_6341_num1_ind['#Mcl[MSun]'])
v_6341_num1 = np.array(data_6341_num1_ind['Unnamed: 1'])
m_6341_num2 = np.array(data_6341_num2_ind['#Mcl[MSun]'])
v_6341_num2 = np.array(data_6341_num2_ind['Unnamed: 1'])

m_6352_num1 = np.array(data_6352_num1_ind['#Mcl[MSun]'])
v_6352_num1 = np.array(data_6352_num1_ind['Unnamed: 1'])
m_6352_num2 = np.array(data_6352_num2_ind['#Mcl[MSun]'])
v_6352_num2 = np.array(data_6352_num2_ind['Unnamed: 1'])

m_6362_num1 = np.array(data_6362_num1_ind['#Mcl[MSun]'])
v_6362_num1 = np.array(data_6362_num1_ind['Unnamed: 1'])
m_6362_num2 = np.array(data_6362_num2_ind['#Mcl[MSun]'])
v_6362_num2 = np.array(data_6362_num2_ind['Unnamed: 1'])

m_6366_num1 = np.array(data_6366_num1_ind['#Mcl[MSun]'])
v_6366_num1 = np.array(data_6366_num1_ind['Unnamed: 1'])
m_6366_num2 = np.array(data_6366_num2_ind['#Mcl[MSun]'])
v_6366_num2 = np.array(data_6366_num2_ind['Unnamed: 1'])

m_6388_num1 = np.array(data_6388_num1_ind['#Mcl[MSun]'])
v_6388_num1 = np.array(data_6388_num1_ind['Unnamed: 1'])
m_6388_num2 = np.array(data_6388_num2_ind['#Mcl[MSun]'])
v_6388_num2 = np.array(data_6388_num2_ind['Unnamed: 1'])

m_6535_num1 = np.array(data_6535_num1_ind['#Mcl[MSun]'])
v_6535_num1 = np.array(data_6535_num1_ind['Unnamed: 1'])
m_6535_num2 = np.array(data_6535_num2_ind['#Mcl[MSun]'])
v_6535_num2 = np.array(data_6535_num2_ind['Unnamed: 1'])

m_6541_num1 = np.array(data_6541_num1_ind['#Mcl[MSun]'])
v_6541_num1 = np.array(data_6541_num1_ind['Unnamed: 1'])
m_6541_num2 = np.array(data_6541_num2_ind['#Mcl[MSun]'])
v_6541_num2 = np.array(data_6541_num2_ind['Unnamed: 1'])

m_6584_num1 = np.array(data_6584_num1_ind['#Mcl[MSun]'])
v_6584_num1 = np.array(data_6584_num1_ind['Unnamed: 1'])
m_6584_num2 = np.array(data_6584_num2_ind['#Mcl[MSun]'])
v_6584_num2 = np.array(data_6584_num2_ind['Unnamed: 1'])

m_6624_num1 = np.array(data_6541_num1_ind['#Mcl[MSun]'])
v_6624_num1 = np.array(data_6541_num1_ind['Unnamed: 1'])
m_6624_num2 = np.array(data_6541_num2_ind['#Mcl[MSun]'])
v_6624_num2 = np.array(data_6541_num2_ind['Unnamed: 1'])

m_6637_num1 = np.array(data_6584_num1_ind['#Mcl[MSun]'])
v_6637_num1 = np.array(data_6584_num1_ind['Unnamed: 1'])
m_6637_num2 = np.array(data_6584_num2_ind['#Mcl[MSun]'])
v_6637_num2 = np.array(data_6584_num2_ind['Unnamed: 1'])

m_6652_num1 = np.array(data_6652_num1_ind['#Mcl[MSun]'])
v_6652_num1 = np.array(data_6652_num1_ind['Unnamed: 1'])
m_6652_num2 = np.array(data_6652_num2_ind['#Mcl[MSun]'])
v_6652_num2 = np.array(data_6652_num2_ind['Unnamed: 1'])

m_6656_num1 = np.array(data_6656_num1_ind['#Mcl[MSun]'])
v_6656_num1 = np.array(data_6656_num1_ind['Unnamed: 1'])
m_6656_num2 = np.array(data_6656_num2_ind['#Mcl[MSun]'])
v_6656_num2 = np.array(data_6656_num2_ind['Unnamed: 1'])

m_6681_num1 = np.array(data_6681_num1_ind['#Mcl[MSun]'])
v_6681_num1 = np.array(data_6681_num1_ind['Unnamed: 1'])
m_6681_num2 = np.array(data_6681_num2_ind['#Mcl[MSun]'])
v_6681_num2 = np.array(data_6681_num2_ind['Unnamed: 1'])

m_6717_num1 = np.array(data_6717_num1_ind['#Mcl[MSun]'])
v_6717_num1 = np.array(data_6717_num1_ind['Unnamed: 1'])
m_6717_num2 = np.array(data_6717_num2_ind['#Mcl[MSun]'])
v_6717_num2 = np.array(data_6717_num2_ind['Unnamed: 1'])

m_6723_num1 = np.array(data_6723_num1_ind['#Mcl[MSun]'])
v_6723_num1 = np.array(data_6723_num1_ind['Unnamed: 1'])
m_6723_num2 = np.array(data_6723_num2_ind['#Mcl[MSun]'])
v_6723_num2 = np.array(data_6723_num2_ind['Unnamed: 1'])

m_6809_num1 = np.array(data_6809_num1_ind['#Mcl[MSun]'])
v_6809_num1 = np.array(data_6809_num1_ind['Unnamed: 1'])
m_6809_num2 = np.array(data_6809_num2_ind['#Mcl[MSun]'])
v_6809_num2 = np.array(data_6809_num2_ind['Unnamed: 1'])

m_6838_num1 = np.array(data_6838_num1_ind['#Mcl[MSun]'])
v_6838_num1 = np.array(data_6838_num1_ind['Unnamed: 1'])
m_6838_num2 = np.array(data_6838_num2_ind['#Mcl[MSun]'])
v_6838_num2 = np.array(data_6838_num2_ind['Unnamed: 1'])

m_6934_num1 = np.array(data_6934_num1_ind['#Mcl[MSun]'])
v_6934_num1 = np.array(data_6934_num1_ind['Unnamed: 1'])
m_6934_num2 = np.array(data_6934_num2_ind['#Mcl[MSun]'])
v_6934_num2 = np.array(data_6934_num2_ind['Unnamed: 1'])

m_6981_num1 = np.array(data_6981_num1_ind['#Mcl[MSun]'])
v_6981_num1 = np.array(data_6981_num1_ind['Unnamed: 1'])
m_6981_num2 = np.array(data_6981_num2_ind['#Mcl[MSun]'])
v_6981_num2 = np.array(data_6981_num2_ind['Unnamed: 1'])

m_7089_num1 = np.array(data_7089_num1_ind['#Mcl[MSun]'])
v_7089_num1 = np.array(data_7089_num1_ind['Unnamed: 1'])
m_7089_num2 = np.array(data_7089_num2_ind['#Mcl[MSun]'])
v_7089_num2 = np.array(data_7089_num2_ind['Unnamed: 1'])

m_7099_num1 = np.array(data_7099_num1_ind['#Mcl[MSun]'])
v_7099_num1 = np.array(data_7099_num1_ind['Unnamed: 1'])
m_7099_num2 = np.array(data_7099_num2_ind['#Mcl[MSun]'])
v_7099_num2 = np.array(data_7099_num2_ind['Unnamed: 1'])

# %%
#all together: 3201, 4590, 4833, 5286 

f, ((ax31, ax32),(ax33,ax34)) = plt.subplots(2, 2)


ax31.plot(m_3201_num1,v_3201_num1, 'o', c='black',mfc="None",label='1+2')
ax31.set_zorder(1)
ax31.plot(m_3201_num2,v_3201_num2, 'o',c='gray',mfc="None", label='2+2')
ax31.set_zorder(2)
ax31.plot(m_3201,v_3201, '*',c='blue',label='NGC 3201')
ax31.set_zorder(3)
ax31.set_title('NGC 3201')
ax31.set_xlabel('Mass(Msun)')
ax31.set_ylabel('Velocity(km/s)')
ax31.set_yscale('log')
ax31.legend(loc="lower right")


ax32.plot(m_4590_num1,v_4590_num1, 'o', c='black',mfc="None",label='1+2')
ax32.set_zorder(1)
ax32.plot(m_4590_num2,v_4590_num2, 'o',c='gray',mfc="None", label='2+2')
ax32.set_zorder(2)
ax32.plot(m_4590,v_4590, '*',c='blue',label='NGC 4590')
ax32.set_zorder(3)
ax32.set_title('NGC 4590')
ax32.set_xlabel('Mass(Msun)')
ax32.set_ylabel('Velocity(km/s)')
ax32.set_yscale('log')
ax32.legend(loc="lower right")

ax33.plot(m_4833_num1,v_4833_num1, 'o', c='black',mfc="None",label='1+2')
ax33.set_zorder(1)
ax33.plot(m_4833_num2,v_4833_num2, 'o',c='gray',mfc="None", label='2+2')
ax33.set_zorder(2)
ax33.plot(m_4833,v_4833, '*',c='blue',label='NGC 4833')
ax33.set_zorder(3)
ax33.set_title('NGC 4833')
ax33.set_xlabel('Mass(Msun)')
ax33.set_ylabel('Velocity(km/s)')
ax33.set_yscale('log')
ax33.legend(loc="lower right")


ax34.plot(m_5286_num1,v_5286_num1, 'o', c='black',mfc="None",label='1+2')
ax34.set_zorder(1)
ax34.plot(m_5286_num2,v_5286_num2, 'o',c='gray',mfc="None", label='2+2')
ax34.set_zorder(2)
ax34.plot(m_5286 ,v_5286 , '*',c='blue',label='NGC 5286 ')
ax34.set_zorder(3)
ax34.set_title('NGC 5286 ')
ax34.set_xlabel('Mass(Msun)')
ax34.set_ylabel('Velocity(km/s)')
ax34.set_yscale('log')
ax34.legend(loc="lower right")


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Everything: 5927, 6101, 6121, 6171

f, ((ax35, ax36),(ax37,ax38)) = plt.subplots(2, 2)


ax35.plot(m_5927_num1,v_5927_num1, 'o', c='black',mfc="None",label='1+2')
ax35.set_zorder(1)
ax35.plot(m_5927_num2,v_5927_num2, 'o',c='gray',mfc="None", label='2+2')
ax35.set_zorder(2)
ax35.plot(m_5927,v_5927, '*',c='blue',label='NGC 5927')
ax35.set_zorder(3)
ax35.set_title('NGC 5927')
ax35.set_xlabel('Mass(Msun)')
ax35.set_ylabel('Velocity(km/s)')
ax35.set_yscale('log')
ax35.legend(loc="lower right")

ax36.plot(m_6101_num1,v_6101_num1, 'o', c='black',mfc="None",label='1+2')
ax36.set_zorder(1)
ax36.plot(m_6101_num2,v_6101_num2, 'o',c='gray',mfc="None", label='2+2')
ax36.set_zorder(2)
ax36.plot(m_6101,v_6101, '*',c='blue',label='NGC 6101')
ax36.set_zorder(3)
ax36.set_title('NGC 6101')
ax36.set_xlabel('Mass(Msun)')
ax36.set_ylabel('Velocity(km/s)')
ax36.set_yscale('log')
ax36.legend(loc="lower right")


ax37.plot(m_6121_num1,v_6121_num1, 'o', c='black',mfc="None",label='1+2')
ax37.set_zorder(1)
ax37.plot(m_6121_num2,v_6121_num2, 'o',c='gray',mfc="None", label='2+2')
ax37.set_zorder(2)
ax37.plot(m_6121,v_6121, '*',c='blue',label='NGC 6121')
ax37.set_zorder(3)
ax37.set_title('NGC 6121')
ax37.set_xlabel('Mass(Msun)')
ax37.set_ylabel('Velocity(km/s)')
ax37.set_yscale('log')
ax37.legend(loc="lower right")

ax38.plot(m_6171_num1,v_6171_num1, 'o', c='black',mfc="None",label='1+2')
ax38.set_zorder(1)
ax38.plot(m_6171_num2,v_6171_num2, 'o',c='gray',mfc="None", label='2+2')
ax38.set_zorder(2)
ax38.plot(m_6171,v_6171, '*',c='blue',label='NGC 6171')
ax38.set_zorder(3)
ax38.set_title('NGC 6171')
ax38.set_xlabel('Mass(Msun)')
ax38.set_ylabel('Velocity(km/s)')
ax38.set_yscale('log')
ax38.legend(loc="lower right")


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Everything: NGC 6218, 6254, 6304, 6341

f, ((ax39, ax40),(ax41,ax42)) = plt.subplots(2, 2)

ax39.plot(m_6218_num1,v_6218_num1, 'o', c='black',mfc="None",label='1+2')
ax39.set_zorder(1)
ax39.plot(m_6218_num2,v_6218_num2, 'o',c='gray',mfc="None", label='2+2')
ax39.set_zorder(2)
ax39.plot(m_6218,v_6218, '*',c='blue',label='NGC 6218')
ax39.set_zorder(3)
ax39.set_title('NGC 6218')
ax39.set_xlabel('Mass(Msun)')
ax39.set_ylabel('Velocity(km/s)')
ax39.set_yscale('log')
ax39.legend(loc="lower right")

ax40.plot(m_6254_num1,v_6254_num1, 'o', c='black',mfc="None",label='1+2')
ax40.set_zorder(1)
ax40.plot(m_6254_num2,v_6254_num2, 'o',c='gray',mfc="None", label='2+2')
ax40.set_zorder(2)
ax40.plot(m_6254,v_6254, '*',c='blue',label='NGC 6254')
ax40.set_zorder(3)
ax40.set_title('NGC 6254')
ax40.set_xlabel('Mass(Msun)')
ax40.set_ylabel('Velocity(km/s)')
ax40.set_yscale('log')
ax40.legend(loc="lower right")


ax41.plot(m_6304_num1,v_6304_num1, 'o', c='black',mfc="None",label='1+2')
ax41.set_zorder(1)
ax41.plot(m_6304_num2,v_6304_num2, 'o',c='gray',mfc="None", label='2+2')
ax41.set_zorder(2)
ax41.plot(m_6304,v_6304, '*',c='blue',label='NGC 6304')
ax41.set_zorder(3)
ax41.set_title('NGC 6304')
ax41.set_xlabel('Mass(Msun)')
ax41.set_ylabel('Velocity(km/s)')
ax41.set_yscale('log')
ax41.legend(loc="lower right")

ax42.plot(m_6341_num1,v_6341_num1, 'o', c='black',mfc="None",label='1+2')
ax42.set_zorder(1)
ax42.plot(m_6341_num2,v_6341_num2, 'o',c='gray',mfc="None", label='2+2')
ax42.set_zorder(2)
ax42.plot(m_6341,v_6341, '*',c='blue',label='NGC 6341')
ax42.set_zorder(3)
ax42.set_title('NGC 6341')
ax42.set_xlabel('Mass(Msun)')
ax42.set_ylabel('Velocity(km/s)')
ax42.set_yscale('log')
ax42.legend(loc="lower right")


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Everything: NGC 6352, 6362, 6366, 6388

f, ((ax43,ax44),(ax45,ax46)) = plt.subplots(2, 2)


ax43.plot(m_6352_num1,v_6352_num1, 'o', c='black',mfc="None",label='1+2')
ax43.set_zorder(1)
ax43.plot(m_6352_num2,v_6352_num2, 'o',c='gray',mfc="None", label='2+2')
ax43.set_zorder(2)
ax43.plot(m_6352,v_6352, '*',c='blue',label='NGC 6352')
ax43.set_zorder(3)
ax43.set_title('NGC 6352')
ax43.set_xlabel('Mass(Msun)')
ax43.set_ylabel('Velocity(km/s)')
ax43.set_yscale('log')
ax43.legend(loc="lower right")


ax44.plot(m_6362_num1,v_6362_num1, 'o', c='black',mfc="None",label='1+2')
ax44.set_zorder(1)
ax44.plot(m_6362_num2,v_6362_num2, 'o',c='gray',mfc="None", label='2+2')
ax44.set_zorder(2)
ax44.plot(m_6362,v_6362, '*',c='blue',label='NGC 6362')
ax44.set_zorder(3)
ax44.set_title('NGC 6362')
ax44.set_xlabel('Mass(Msun)')
ax44.set_ylabel('Velocity(km/s)')
ax44.set_yscale('log')
ax44.legend(loc="lower right")

ax45.plot(m_6366_num1,v_6366_num1, 'o', c='black',mfc="None",label='1+2')
ax45.set_zorder(1)
ax45.plot(m_6366_num2,v_6366_num2, 'o',c='gray',mfc="None", label='2+2')
ax45.set_zorder(2)
ax45.plot(m_6366,v_6366, '*',c='blue',label='NGC 6366')
ax45.set_zorder(3)
ax45.set_title('NGC 6366')
ax45.set_xlabel('Mass(Msun)')
ax45.set_ylabel('Velocity(km/s)')
ax45.set_yscale('log')
ax45.legend(loc="lower right")

ax46.plot(m_6388_num1,v_6388_num1, 'o', c='black',mfc="None",label='1+2')
ax46.set_zorder(1)
ax46.plot(m_6388_num2,v_6388_num2, 'o',c='gray',mfc="None", label='2+2')
ax46.set_zorder(2)
ax46.plot(m_6388,v_6388, '*',c='blue',label='NGC 6388')
ax46.set_zorder(3)
ax46.set_title('NGC 6388')
ax46.set_xlabel('Mass(Msun)')
ax46.set_ylabel('Velocity(km/s)')
ax46.set_yscale('log')
ax46.legend(loc="lower right")

fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Everything: NGC 6541, 6584, 6624, 6637

f, ((ax47,ax48),(ax49,ax50)) = plt.subplots(2, 2)


ax47.plot(m_6541_num1,v_6541_num1, 'o', c='black',mfc="None",label='1+2')
ax47.set_zorder(1)
ax47.plot(m_6541_num2,v_6541_num2, 'o',c='gray',mfc="None", label='2+2')
ax47.set_zorder(2)
ax47.plot(m_6541,v_6541, '*',c='blue',label='NGC 6541')
ax47.set_zorder(3)
ax47.set_title('NGC 6541')
ax47.set_xlabel('Mass(Msun)')
ax47.set_ylabel('Velocity(km/s)')
ax47.set_yscale('log')
ax47.legend(loc="lower right")


ax48.plot(m_6584_num1,v_6584_num1, 'o', c='black',mfc="None",label='1+2')
ax48.set_zorder(1)
ax48.plot(m_6584_num2,v_6584_num2, 'o',c='gray',mfc="None", label='2+2')
ax48.set_zorder(2)
ax48.plot(m_6584,v_6584, '*',c='blue',label='NGC 6584')
ax48.set_zorder(3)
ax48.set_title('NGC 6584')
ax48.set_xlabel('Mass(Msun)')
ax48.set_ylabel('Velocity(km/s)')
ax48.set_yscale('log')
ax48.legend(loc="lower right")

ax49.plot(m_6624_num1,v_6624_num1, 'o', c='black',mfc="None",label='1+2')
ax49.set_zorder(1)
ax49.plot(m_6624_num2,v_6624_num2, 'o',c='gray',mfc="None", label='2+2')
ax49.set_zorder(2)
ax49.plot(m_6624,v_6624, '*',c='blue',label='NGC 6624')
ax49.set_zorder(3)
ax49.set_title('NGC 6624')
ax49.set_xlabel('Mass(Msun)')
ax49.set_ylabel('Velocity(km/s)')
ax49.set_yscale('log')
ax49.legend(loc="lower right")

ax50.plot(m_6637_num1,v_6637_num1, 'o', c='black',mfc="None",label='1+2')
ax50.set_zorder(1)
ax50.plot(m_6637_num2,v_6637_num2, 'o',c='gray',mfc="None", label='2+2')
ax50.set_zorder(2)
ax50.plot(m_6637,v_6637, '*',c='blue',label='NGC 6637')
ax50.set_zorder(3)
ax50.set_title('NGC 6637')
ax50.set_xlabel('Mass(Msun)')
ax50.set_ylabel('Velocity(km/s)')
ax50.set_yscale('log')
ax50.legend(loc="lower right")


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Everything: NGC 6652, 6656, 6681, 6717


f, ((ax51,ax52),(ax53,ax54)) = plt.subplots(2, 2)


ax51.plot(m_6652_num1,v_6652_num1, 'o', c='black',mfc="None",label='1+2')
ax51.set_zorder(1)
ax51.plot(m_6652_num2,v_6652_num2, 'o',c='gray',mfc="None", label='2+2')
ax51.set_zorder(2)
ax51.plot(m_6652,v_6652, '*',c='blue',label='NGC 6652')
ax51.set_zorder(3)
ax51.set_title('NGC 6652')
ax51.set_xlabel('Mass(Msun)')
ax51.set_ylabel('Velocity(km/s)')
ax51.set_yscale('log')
ax51.legend(loc="lower right")

ax52.plot(m_6656_num1,v_6656_num1, 'o', c='black',mfc="None",label='1+2')
ax52.set_zorder(1)
ax52.plot(m_6656_num2,v_6656_num2, 'o',c='gray',mfc="None", label='2+2')
ax52.set_zorder(2)
ax52.plot(m_6656,v_6656, '*',c='blue',label='NGC 6656')
ax52.set_zorder(3)
ax52.set_title('NGC 6656')
ax52.set_xlabel('Mass(Msun)')
ax52.set_ylabel('Velocity(km/s)')
ax52.set_yscale('log')
ax52.legend(loc="lower right")

ax53.plot(m_6681_num1,v_6681_num1, 'o', c='black',mfc="None",label='1+2')
ax53.set_zorder(1)
ax53.plot(m_6681_num2,v_6681_num2, 'o',c='gray',mfc="None", label='2+2')
ax53.set_zorder(2)
ax53.plot(m_6681,v_6681, '*',c='blue',label='NGC 6681')
ax53.set_zorder(3)
ax53.set_title('NGC 6681')
ax53.set_xlabel('Mass(Msun)')
ax53.set_ylabel('Velocity(km/s)')
ax53.set_yscale('log')
ax53.legend(loc="lower right")

ax54.plot(m_6717_num1,v_6717_num1, 'o', c='black',mfc="None",label='1+2')
ax54.set_zorder(1)
ax54.plot(m_6717_num2,v_6717_num2, 'o',c='gray',mfc="None", label='2+2')
ax54.set_zorder(2)
ax54.plot(m_6717,v_6717, '*',c='blue',label='NGC 6717')
ax54.set_zorder(3)
ax54.set_title('NGC 6717')
ax54.set_xlabel('Mass(Msun)')
ax54.set_ylabel('Velocity(km/s)')
ax54.set_yscale('log')
ax54.legend(loc="lower right")


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
f, ((ax56,ax57),(ax58,ax59)) = plt.subplots(2, 2)


ax56.plot(m_6809_num1,v_6809_num1, 'o', c='black',mfc="None",label='1+2')
ax56.set_zorder(1)
ax56.plot(m_6809_num2,v_6809_num2, 'o',c='gray',mfc="None", label='2+2')
ax56.set_zorder(2)
ax56.plot(m_6809,v_6809, '*',c='blue',label='NGC 6809')
ax56.set_zorder(3)
ax56.set_title('NGC 6809')
ax56.set_xlabel('Mass(Msun)')
ax56.set_ylabel('Velocity(km/s)')
ax56.set_yscale('log')
ax56.legend(loc="lower right")

ax57.plot(m_6838_num1,v_6838_num1, 'o', c='black',mfc="None",label='1+2')
ax57.set_zorder(1)
ax57.plot(m_6838_num2,v_6838_num2, 'o',c='gray',mfc="None", label='2+2')
ax57.set_zorder(2)
ax57.plot(m_6838,v_6838, '*',c='blue',label='NGC 6838')
ax57.set_zorder(3)
ax57.set_title('NGC 6838')
ax57.set_xlabel('Mass(Msun)')
ax57.set_ylabel('Velocity(km/s)')
ax57.set_yscale('log')
ax57.legend(loc="lower right")
            
ax58.plot(m_7089_num1,v_7089_num1, 'o', c='black',mfc="None",label='1+2')
ax58.set_zorder(1)
ax58.plot(m_7089_num2,v_7089_num2, 'o',c='gray',mfc="None", label='2+2')
ax58.set_zorder(2)
ax58.plot(m_7089,v_7089, '*',c='blue',label='NGC 7089')
ax58.set_zorder(3)
ax58.set_title('NGC 7089')
ax58.set_xlabel('Mass(Msun)')
ax58.set_ylabel('Velocity(km/s)')
ax58.set_yscale('log')
ax58.legend(loc="lower right")
            

ax59.plot(m_7099_num1,v_7099_num1, 'o', c='black',mfc="None",label='1+2')
ax59.set_zorder(1)
ax59.plot(m_7099_num2,v_7099_num2, 'o',c='gray',mfc="None", label='2+2')
ax59.set_zorder(2)
ax59.plot(m_7099,v_7099, '*',c='blue',label='NGC 7099')
ax59.set_zorder(3)
ax59.set_title('NGC 7099')
ax59.set_xlabel('Mass(Msun)')
ax59.set_ylabel('Velocity(km/s)')
ax59.set_yscale('log')
ax59.legend(loc="lower right")

fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Making Cumulative Histograms; Had to change the array from strings to floats because it would not plot. 

v3201_1 = pd.Series(v_3201_num1.astype(np.float))
v3201_2 = pd.Series(v_3201_num2.astype(np.float))
v3201 = pd.Series(v_3201)

m3201_1 = pd.Series(m_3201_num1.astype(np.float))
m3201_2 = pd.Series(m_3201_num2.astype(np.float))
m3201 = pd.Series(m_3201)

v4590_1 = pd.Series(v_4590_num1.astype(np.float))
v4590_2 = pd.Series(v_4590_num2.astype(np.float))
v4590 = pd.Series(v_4590)

m4590_1 = pd.Series(m_4590_num1.astype(np.float))
m4590_2 = pd.Series(m_4590_num2.astype(np.float))
m4590 = pd.Series(m_4590)

v4833_1 = pd.Series(v_4833_num1.astype(np.float))
v4833_2 = pd.Series(v_4833_num2.astype(np.float))
v4833 = pd.Series(v_4833)

m4833_1 = pd.Series(m_4833_num1.astype(np.float))
m4833_2 = pd.Series(m_4833_num2.astype(np.float))
m4833 = pd.Series(m_4833)

v5286_1 = pd.Series(v_5286_num1.astype(np.float))
v5286_2 = pd.Series(v_5286_num2.astype(np.float))
v5286 = pd.Series(v_5286)

m5286_1 = pd.Series(m_5286_num1.astype(np.float))
m5286_2 = pd.Series(m_5286_num2.astype(np.float))
m5286 = pd.Series(m_5286)

v5927_1 = pd.Series(v_5927_num1.astype(np.float))
v5927_2 = pd.Series(v_5927_num2.astype(np.float))
v5927 = pd.Series(v_5927)

m5927_1 = pd.Series(m_5927_num1.astype(np.float))
m5927_2 = pd.Series(m_5927_num2.astype(np.float))
m5927 = pd.Series(m_5927)

v6101_1 = pd.Series(v_6101_num1.astype(np.float))
v6101_2 = pd.Series(v_6101_num2.astype(np.float))
v6101 = pd.Series(v_6101)

m6101_1 = pd.Series(m_6101_num1.astype(np.float))
m6101_2 = pd.Series(m_6101_num2.astype(np.float))
m6101 = pd.Series(m_6101)

v6121_1 = pd.Series(v_6121_num1.astype(np.float))
v6121_2 = pd.Series(v_6121_num2.astype(np.float))
v6121 = pd.Series(v_6121)

m6121_1 = pd.Series(m_6121_num1.astype(np.float))
m6121_2 = pd.Series(m_6121_num2.astype(np.float))
m6121 = pd.Series(m_6121)

v6171_1 = pd.Series(v_6171_num1.astype(np.float))
v6171_2 = pd.Series(v_6171_num2.astype(np.float))
v6171 = pd.Series(v_6171)

m6171_1 = pd.Series(m_6171_num1.astype(np.float))
m6171_2 = pd.Series(m_6171_num2.astype(np.float))
m6171 = pd.Series(m_6171)

v6218_1 = pd.Series(v_6218_num1.astype(np.float))
v6218_2 = pd.Series(v_6218_num2.astype(np.float))
v6218 = pd.Series(v_6218)

m6218_1 = pd.Series(m_6218_num1.astype(np.float))
m6218_2 = pd.Series(m_6218_num2.astype(np.float))
m6218 = pd.Series(m_6218)

v6121_1 = pd.Series(v_6121_num1.astype(np.float))
v6121_2 = pd.Series(v_6121_num2.astype(np.float))
v6121 = pd.Series(v_6121)

m6121_1 = pd.Series(m_6121_num1.astype(np.float))
m6121_2 = pd.Series(m_6121_num2.astype(np.float))
m6121 = pd.Series(m_6121)
##
v6352_1 = pd.Series(v_6352_num1.astype(np.float))
v6352_2 = pd.Series(v_6352_num2.astype(np.float))
v6352 = pd.Series(v_6352)

m6352_1 = pd.Series(m_6352_num1.astype(np.float))
m6352_2 = pd.Series(m_6352_num2.astype(np.float))
m6352 = pd.Series(m_6352)
##
v6254_1 = pd.Series(v_6254_num1.astype(np.float))
v6254_2 = pd.Series(v_6254_num2.astype(np.float))
v6254 = pd.Series(v_6254)

m6254_1 = pd.Series(m_6254_num1.astype(np.float))
m6254_2 = pd.Series(m_6254_num2.astype(np.float))
m6254 = pd.Series(m_6254)

v6304_1 = pd.Series(v_6304_num1.astype(np.float))
v6304_2 = pd.Series(v_6304_num2.astype(np.float))
v6304 = pd.Series(v_6304)

m6304_1 = pd.Series(m_6304_num1.astype(np.float))
m6304_2 = pd.Series(m_6304_num2.astype(np.float))
m6304 = pd.Series(m_6304)

v6341_1 = pd.Series(v_6341_num1.astype(np.float))
v6341_2 = pd.Series(v_6341_num2.astype(np.float))
v6341 = pd.Series(v_6341)

m6341_1 = pd.Series(m_6341_num1.astype(np.float))
m6341_2 = pd.Series(m_6341_num2.astype(np.float))
m6341 = pd.Series(m_6341)

v6352_1 = pd.Series(v_6352_num1.astype(np.float))
v6352_2 = pd.Series(v_6352_num2.astype(np.float))
v6352 = pd.Series(v_6352)

m6352_1 = pd.Series(m_6352_num1.astype(np.float))
m6352_2 = pd.Series(m_6352_num2.astype(np.float))
m6352 = pd.Series(m_6352)

##

v6362_1 = pd.Series(v_6362_num1.astype(np.float))
v6362_2 = pd.Series(v_6362_num2.astype(np.float))
v6362 = pd.Series(v_6362)

m6362_1 = pd.Series(m_6362_num1.astype(np.float))
m6362_2 = pd.Series(m_6362_num2.astype(np.float))
m6362 = pd.Series(m_6362)

v6366_1 = pd.Series(v_6366_num1.astype(np.float))
v6366_2 = pd.Series(v_6366_num2.astype(np.float))
v6366 = pd.Series(v_6366)

m6366_1 = pd.Series(m_6366_num1.astype(np.float))
m6366_2 = pd.Series(m_6366_num2.astype(np.float))
m6366 = pd.Series(m_6366)

##

v6388_1 = pd.Series(v_6388_num1.astype(np.float))
v6388_2 = pd.Series(v_6388_num2.astype(np.float))
v6388 = pd.Series(v_6388)

m6388_1 = pd.Series(m_6388_num1.astype(np.float))
m6388_2 = pd.Series(m_6388_num2.astype(np.float))
m6388 = pd.Series(m_6388)

v6541_1 = pd.Series(v_6541_num1.astype(np.float))
v6541_2 = pd.Series(v_6541_num2.astype(np.float))
v6541 = pd.Series(v_6541)

m6541_1 = pd.Series(m_6541_num1.astype(np.float))
m6541_2 = pd.Series(m_6541_num2.astype(np.float))
m6541 = pd.Series(m_6541)

v6584_1 = pd.Series(v_6584_num1.astype(np.float))
v6584_2 = pd.Series(v_6584_num2.astype(np.float))
v6584 = pd.Series(v_6584)

m6584_1 = pd.Series(m_6584_num1.astype(np.float))
m6584_2 = pd.Series(m_6584_num2.astype(np.float))
m6584 = pd.Series(m_6584)

##


v6624_1 = pd.Series(v_6624_num1.astype(np.float))
v6624_2 = pd.Series(v_6624_num2.astype(np.float))
v6624 = pd.Series(v_6624)

m6624_1 = pd.Series(m_6624_num1.astype(np.float))
m6624_2 = pd.Series(m_6624_num2.astype(np.float))
m6624 = pd.Series(m_6624)

v6637_1 = pd.Series(v_6637_num1.astype(np.float))
v6637_2 = pd.Series(v_6637_num2.astype(np.float))
v6637 = pd.Series(v_6637)

m6637_1 = pd.Series(m_6637_num1.astype(np.float))
m6637_2 = pd.Series(m_6637_num2.astype(np.float))
m6637 = pd.Series(m_6637)

v6652_1 = pd.Series(v_6652_num1.astype(np.float))
v6652_2 = pd.Series(v_6652_num2.astype(np.float))
v6652 = pd.Series(v_6652)

m6652_1 = pd.Series(m_6652_num1.astype(np.float))
m6652_2 = pd.Series(m_6652_num2.astype(np.float))
m6652 = pd.Series(m_6652)

v6717_1 = pd.Series(v_6717_num1.astype(np.float))
v6717_2 = pd.Series(v_6717_num2.astype(np.float))
v6717 = pd.Series(v_6717)

m6717_1 = pd.Series(m_6717_num1.astype(np.float))
m6717_2 = pd.Series(m_6717_num2.astype(np.float))
m6717 = pd.Series(m_6717)

##

v6656_1 = pd.Series(v_6656_num1.astype(np.float))
v6656_2 = pd.Series(v_6656_num2.astype(np.float))
v6656 = pd.Series(v_6656)

m6656_1 = pd.Series(m_6656_num1.astype(np.float))
m6656_2 = pd.Series(m_6656_num2.astype(np.float))
m6656 = pd.Series(m_6656)

v6681_1 = pd.Series(v_6681_num1.astype(np.float))
v6681_2 = pd.Series(v_6681_num2.astype(np.float))
v6681 = pd.Series(v_6681)

m6681_1 = pd.Series(m_6681_num1.astype(np.float))
m6681_2 = pd.Series(m_6681_num2.astype(np.float))
m6681 = pd.Series(m_6681)

v6723_1 = pd.Series(v_6723_num1.astype(np.float))
v6723_2 = pd.Series(v_6723_num2.astype(np.float))
v6723 = pd.Series(v_6723)

m6723_1 = pd.Series(m_6723_num1.astype(np.float))
m6723_2 = pd.Series(m_6723_num2.astype(np.float))
m6723 = pd.Series(m_6723)

##

v6809_1 = pd.Series(v_6809_num1.astype(np.float))
v6809_2 = pd.Series(v_6809_num2.astype(np.float))
v6809 = pd.Series(v_6809)

m6809_1 = pd.Series(m_6809_num1.astype(np.float))
m6809_2 = pd.Series(m_6809_num2.astype(np.float))
m6809 = pd.Series(m_6809)

v6838_1 = pd.Series(v_6838_num1.astype(np.float))
v6838_2 = pd.Series(v_6838_num2.astype(np.float))
v6838 = pd.Series(v_6838)

m6838_1 = pd.Series(m_6838_num1.astype(np.float))
m6838_2 = pd.Series(m_6838_num2.astype(np.float))
m6838 = pd.Series(m_6838)

v7089_1 = pd.Series(v_7089_num1.astype(np.float))
v7089_2 = pd.Series(v_7089_num2.astype(np.float))
v7089 = pd.Series(v_7089)

m7089_1 = pd.Series(m_7089_num1.astype(np.float))
m7089_2 = pd.Series(m_7089_num2.astype(np.float))
m7089 = pd.Series(m_7089)

v7099_1 = pd.Series(v_7099_num1.astype(np.float))
v7099_2 = pd.Series(v_7099_num2.astype(np.float))
v7099 = pd.Series(v_7099)

m7099_1 = pd.Series(m_7099_num1.astype(np.float))
m7099_2 = pd.Series(m_7099_num2.astype(np.float))
m7099 = pd.Series(m_7099)

# %%
#Making new tables for the upper and lower limit of masses

t1_3201 = Table ([m3201_1,v3201_1],names=('Mass1', 'Velocity1'))
t1_3201.add_index('Mass1')
x3201 = t1_3201.loc[0.957:1.244]
t2_3201 = Table ([m3201_2,v3201_2],names=('Mass2', 'Velocity2'))
t2_3201.add_index('Mass2')
y3201 = t2_3201.loc[0.957:1.244]

t1_4590 = Table ([m4590_1,v4590_1],names=('Mass1', 'Velocity1'))
t1_4590.add_index('Mass1')
x4590 = t1_4590.loc[0.889:1.32]
t2_4590 = Table ([m4590_2,v4590_2],names=('Mass2', 'Velocity2'))
t2_4590.add_index('Mass2')
y4590 = t2_4590.loc[0.889:1.32]

t1_4833 = Table ([m4833_1,v4833_1],names=('Mass1', 'Velocity1'))
t1_4833.add_index('Mass1')
x4833 = t1_4833.loc[0.835:1.19]
t2_4833 = Table ([m4833_2,v4833_2],names=('Mass2', 'Velocity2'))
t2_4833.add_index('Mass2')
y4833 = t2_4833.loc[0.835:1.19]

##
t1_5286 = Table ([m5286_1,v5286_1],names=('Mass1', 'Velocity1'))
t1_5286.add_index('Mass1')
x5286 = t1_5286.loc[0.896:1.478]
t2_5286 = Table ([m5286_2,v5286_2],names=('Mass2', 'Velocity2'))
t2_5286.add_index('Mass2')
y5286 = t2_5286.loc[0.896:1.478]

t1_5927 = Table ([m5927_1,v5927_1],names=('Mass1', 'Velocity1'))
t1_5927.add_index('Mass1')
x5927 = t1_5927.loc[1.059:1.638]
t2_5927 = Table ([m5927_2,v5927_2],names=('Mass2', 'Velocity2'))
t2_5927.add_index('Mass2')
y5927 = t2_5927.loc[1.059:1.638]

t1_6101 = Table ([m6101_1, v6101_1],names=('Mass1', 'Velocity1'))
t1_6101.add_index('Mass1')
x6101 = t1_6101.loc[0.847:1.173]
t2_6101 = Table ([m6101_2, v6101_2],names=('Mass2', 'Velocity2'))
t2_6101.add_index('Mass2')
y6101 = t2_6101.loc[0.847:1.173]

##
t1_6121 = Table ([m6121_1,v6121_1],names=('Mass1', 'Velocity1'))
t1_6121.add_index('Mass1')
x6121 = t1_6121.loc[0.93:1.128]
t2_6121 = Table ([m6121_2,v6121_2],names=('Mass2', 'Velocity2'))
t2_6121.add_index('Mass2')
y6121 = t2_6121.loc[0.93:1.128]

t1_6171 = Table ([m6171_1,v6171_1],names=('Mass1', 'Velocity1'))
t1_6171.add_index('Mass1')
x6171 = t1_6171.loc[0.985:1.368]
t2_6171 = Table ([m6171_2,v6171_2],names=('Mass2', 'Velocity2'))
t2_6171.add_index('Mass2')
y6171 = t2_6171.loc[0.985:1.368]

t1_6218 = Table ([m6218_1,v6218_1],names=('Mass1', 'Velocity1'))
t1_6218.add_index('Mass1')
x6218 = t1_6218.loc[0.865:1.318]
t2_6218 = Table ([m6218_2,v6218_2],names=('Mass2', 'Velocity2'))
t2_6218.add_index('Mass2')
y6218 = t2_6218.loc[0.865:1.318]

t1_6254 = Table ([m6254_1,v6254_1],names=('Mass1', 'Velocity1'))
t1_6254.add_index('Mass1')
x6254 = t1_6254.loc[0.887:1.25]
t2_6254 = Table ([m6254_2,v6254_2],names=('Mass2', 'Velocity2'))
t2_6254.add_index('Mass2')
y6254 = t2_6254.loc[0.887:1.25]

t1_6304 = Table ([m6304_1,v6304_1],names=('Mass1', 'Velocity1'))
t1_6304.add_index('Mass1')
x6304 = t1_6304.loc[1.015:1.524]
t2_6304 = Table ([m6304_2,v6304_2],names=('Mass2', 'Velocity2'))
t2_6304.add_index('Mass2')
y6304 = t2_6304.loc[1.015:1.524]


t1_6341 = Table ([m6341_1,v6341_1],names=('Mass1', 'Velocity1'))
t1_6341.add_index('Mass1')
x6341 = t1_6341.loc[0.851:1.293]
t2_6341 = Table ([m6254_2,v6254_2],names=('Mass2', 'Velocity2'))
t2_6341.add_index('Mass2')
y6341 = t2_6341.loc[0.851:1.293]


##

t1_6352 = Table ([m6352_1, v6352_1],names=('Mass1', 'Velocity1'))
t1_6352.add_index('Mass1')
x6352 = t1_6352.loc[0.972:1.459]
t2_6352 = Table ([m6352_2, v6352_2],names=('Mass2', 'Velocity2'))
t2_6352.add_index('Mass2')
y6352 = t2_6352.loc[0.972:1.459]


t1_6362 = Table ([m6362_1,v6362_1],names=('Mass1', 'Velocity1'))
t1_6362.add_index('Mass1')
x6362 = t1_6362.loc[0.9:1.228]
t2_6362 = Table ([m6362_2,v6362_2],names=('Mass2', 'Velocity2'))
t2_6362.add_index('Mass2')
y6362 = t2_6362.loc[0.9:1.228]

t1_6366 = Table ([m6366_1,v6366_1],names=('Mass1', 'Velocity1'))
t1_6366.add_index('Mass1')
x6366 = t1_6366.loc[1.002:1.263]
t2_6366 = Table ([m6366_2,v6366_2],names=('Mass2', 'Velocity2'))
t2_6366.add_index('Mass2')
y6366 = t2_6366.loc[1.002:1.263]

##

t1_6388 = Table ([m6388_1,v6388_1],names=('Mass1', 'Velocity1'))
t1_6388.add_index('Mass1')
x6388 = t1_6388.loc[1.03:1.57]
t2_6388 = Table ([m6388_2,v6388_2],names=('Mass2', 'Velocity2'))
t2_6388.add_index('Mass2')
y6388 = t2_6388.loc[1.03:1.57]

t1_6541 = Table ([m6541_1,v6541_1],names=('Mass1', 'Velocity1'))
t1_6541.add_index('Mass1')
x6541 = t1_6362.loc[0.854:1.481]
t2_6541 = Table ([m6541_2,v6541_2],names=('Mass2', 'Velocity2'))
t2_6541.add_index('Mass2')
y6541 = t2_6541.loc[0.854:1.481]

t1_6584 = Table ([m6584_1,v6584_1],names=('Mass1', 'Velocity1'))
t1_6584.add_index('Mass1')
x6584 = t1_6218.loc[0.926:1.191]
t2_6584 = Table ([m6584_2,v6584_2],names=('Mass2', 'Velocity2'))
t2_6584.add_index('Mass2')
y6584 = t2_6584.loc[0.926:1.191]

##

t1_6624 = Table ([m6624_1,v6624_1],names=('Mass1', 'Velocity1'))
t1_6624.add_index('Mass1')
x6624 = t1_6352.loc[1.031:1.547]
t2_6624 = Table ([m6624_2,v6624_2],names=('Mass2', 'Velocity2'))
t2_6624.add_index('Mass2')
y6624 = t2_6624.loc[1.031:1.547]

t1_6637 = Table ([m6637_1,v6637_1],names=('Mass1', 'Velocity1'))
t1_6637.add_index('Mass1')
x6637 = t1_6637.loc[0.977:1.598]
t2_6637 = Table ([m6637_2,v6637_2],names=('Mass2', 'Velocity2'))
t2_6637.add_index('Mass2')
y6637= t2_6637.loc[0.977:1.598]

t1_6652 = Table ([m6652_1, v6652_1],names=('Mass1', 'Velocity1'))
t1_6652.add_index('Mass1')
x6652 = t1_6652.loc[0.981:1.397]
t2_6652 = Table ([m6652_2, v6652_2],names=('Mass2', 'Velocity2'))
t2_6652.add_index('Mass2')
y6652 = t2_6652.loc[0.981:1.397]

##

t1_6656 = Table ([m6656_1,v6656_1],names=('Mass1', 'Velocity1'))
t1_6656.add_index('Mass1')
x6656 = t1_6656.loc[0.836:1.272]  
t2_6656 = Table ([m6656_2,v6656_2],names=('Mass2', 'Velocity2'))
t2_6656.add_index('Mass2')
y6656 = t2_6656.loc[0.836:1.272]  

t1_6681 = Table ([m6681_1,v6681_1],names=('Mass1', 'Velocity1'))
t1_6681.add_index('Mass1')
x6681 = t1_6681.loc[0.914:1.312]
t2_6681 = Table ([m6681_2,v6681_2],names=('Mass2', 'Velocity2'))
t2_6681.add_index('Mass2')
y6681= t2_6681.loc[0.914:1.312]

t1_6717 = Table ([m6717_1,v6717_1],names=('Mass1', 'Velocity1'))
t1_6717.add_index('Mass1')
x6717 = t1_6717.loc[0.917:1.288]
t2_6717= Table ([m6717_2,v6717_2],names=('Mass2', 'Velocity2'))
t2_6717.add_index('Mass2')
y6717 = t2_6717.loc[0.917:1.288]

##

t1_6723 = Table ([m6723_1,v6723_1],names=('Mass1', 'Velocity1'))
t1_6723.add_index('Mass1')
x6723 = t1_6723.loc[0.947:1.443]
t2_6723 = Table ([m6723_2,v6723_2],names=('Mass2', 'Velocity2'))
t2_6723.add_index('Mass2')
y6723 = t2_6723.loc[0.947:1.443]

t1_6809 = Table ([m6809_1,v6809_1],names=('Mass1', 'Velocity1'))
t1_6809.add_index('Mass1')
x6809 = t1_6809.loc[0.863:1.16]
t2_6809 = Table ([m6809_2,v6809_2],names=('Mass2', 'Velocity2'))
t2_6809.add_index('Mass2')
y6809= t2_6809.loc[0.863:1.16]

t1_6838 = Table ([m6838_1,v6838_1],names=('Mass1', 'Velocity1'))
t1_6838.add_index('Mass1')
x6838 = t1_6838.loc[0.957:1.244]
t2_6838= Table ([m6838_2,v6838_2],names=('Mass2', 'Velocity2'))
t2_6838.add_index('Mass2')
y6838 = t2_6838.loc[0.957:1.244]

##

t1_7089 = Table ([m7089_1,v7089_1],names=('Mass1', 'Velocity1'))
t1_7089.add_index('Mass1')
x7089 = t1_7089.loc[0.878:1.412]
t2_7089 = Table ([m7089_2,v7089_2],names=('Mass2', 'Velocity2'))
t2_7089.add_index('Mass2')
y7089= t2_7089.loc[0.878:1.412]

t1_7099 = Table ([m7099_1,v7099_1],names=('Mass1', 'Velocity1'))
t1_7099.add_index('Mass1')
x7099 = t1_6838.loc[0.838:1.315]
t2_7099= Table ([m7099_2,v7099_2],names=('Mass2', 'Velocity2'))
t2_7099.add_index('Mass2')
y7099 = t2_7099.loc[0.838:1.315]

# %%
plt.plot(x6809['Mass1'], x6809['Velocity1'], 'o', c='black',label='1+2',zorder=1)
plt.plot(y6809['Mass2'], y6809['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6809,v_6809, '*',c='blue',label='NGC 6809', zorder=3)
plt.axhline(y=15.3,xmin=0,xmax=3.5,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC6809',fontsize = 'large')
plt.xlabel('Mass ($M_{\odot}$)')
plt.ylabel('Log Velocity(km/s)')
plt.yscale('log')
plt.legend(loc="lower right")
plt.savefig('NGC_6809')

# %%
ln3201 = np.linspace(min(v3201), max(v3201), len(v3201))
mean3201, v = stats.maxwell.fit(v3201) #finding mean and variance 
pdf_3201 = stats.maxwell.cdf(ln3201, scale = 5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x3201['Mass1'],x3201['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y3201['Mass2'],y3201['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_3201,v_3201, '*',c='blue',label='NGC3201',zorder=3)
plt.axhline(y=17.3,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 3201')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln3201, pdf_3201,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v3201,histtype='step',normed=True,cumulative=True, bins=9, color='blue',linewidth=1.5,label='NGC3201')
plt.xlim(0,14.5)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x3201['Velocity1'],cumulative=True,histtype='step', normed=1, bins=40, color='black',linewidth=1.5,label='1+2')
plt.hist(y3201['Velocity2'],cumulative=True,histtype='step', normed=1, bins=40, color = 'gray',linewidth=1.5,label = '2+2')
plt.hist(v3201,cumulative=True,histtype='step', normed=1, bins=9, color = 'blue',linewidth=1.5,label = 'NGC3201')
plt.legend(loc="lower right",fontsize = 'small')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,14.5)

plt.subplot2grid((3,3), (2,2))
plt.hist(x3201['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y3201['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m3201,cumulative=True,histtype='step', normed=1, bins=9, linewidth=1.5,color = 'blue',label = 'NGC3201')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC3201.png')

# %%
ln4590 = np.linspace(min(v4590), max(v4590), len(v4590))
mean4590, v = stats.maxwell.fit(v4590) #finding mean and variance 
pdf_4590 = stats.maxwell.cdf(ln4590, scale = 2.5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x4590['Mass1'],x4590['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y4590['Mass2'],y4590['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_4590,v_4590, '*',c='blue',label='NGC4590',zorder=3)
plt.axhline(y=14.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 4590',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln4590, pdf_4590,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v4590,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC4590')
plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x4590['Velocity1'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color='black',label='1+2')
plt.hist(y4590['Velocity2'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v4590,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC4590')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,12)

plt.subplot2grid((3,3), (2,2))
plt.hist(x4590['Mass1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y4590['Mass2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m4590,cumulative=True,histtype='step', normed=1, bins=8,linewidth=1.5, color = 'blue',label = 'NGC4590')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC4590.png')

# %%
ln4833 = np.linspace(min(v4833), max(v4833), len(v4833))
mean4833, v = stats.maxwell.fit(v4833) #finding mean and variance 
pdf_4833 = stats.maxwell.cdf(ln4833, scale = 2.5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x4833['Mass1'],x4833['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y4833['Mass2'],y4833['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_4833,v_4833, '*',c='blue',label='NGC4833',zorder=3)
plt.axhline(y=22.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 4833',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln4833, pdf_4833,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v4833,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC4833')
plt.xlim(0,17)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x4833['Velocity1'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color='black',label='1+2')
plt.hist(y4833['Velocity2'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v4833,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC4833')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,17)

plt.subplot2grid((3,3), (2,2))
plt.hist(x4833['Mass1'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color='black',label='1+2')
plt.hist(y4833['Mass2'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m4833,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC4833')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC4833.png')

# %%
ln5286 = np.linspace(min(v5286), max(v5286), len(v5286))
mean5286, v = stats.maxwell.fit(v5286) #finding mean and variance 
pdf_5286 = stats.maxwell.cdf(ln5286, scale = 8.1) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x5286['Mass1'],x5286['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y5286['Mass2'],y5286['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_5286,v_5286, '*',c='blue',label='NGC5286',zorder=3)
plt.axhline(y=37.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 5286',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln5286, pdf_5286,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v5286,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC5286')
plt.xlim(0,55)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x5286['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y5286['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v5286,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC5286')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,55)

plt.subplot2grid((3,3), (2,2))
plt.hist(x5286['Mass1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y5286['Mass2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m5286,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC5286')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC5286.png')

# %%
ln5927 = np.linspace(min(v5927), max(v5927), len(v5927))
mean5927, v = stats.maxwell.fit(v5927) #finding mean and variance 
pdf_5927 = stats.maxwell.cdf(ln5927, scale = 8.1) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x5927['Mass1'],x5927['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y5927['Mass2'],y5927['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_5927,v_5927, '*',c='blue',label='NGC5927',zorder=3)
plt.axhline(y=27.1,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 5927',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln5927, pdf_5927,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v5927,histtype='step',normed=True,cumulative=True, bins=10, color='blue',linewidth=1.5,label='NGC5927')
plt.xlim(0,31)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x5927['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y5927['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v5927,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC5927')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,31)

plt.subplot2grid((3,3), (2,2))
plt.hist(x5927['Mass1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y5927['Mass2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m5927,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC5927')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC5927.png')

# %%
ln6101 = np.linspace(min(v6101), max(v6101), len(v6101))
mean6101, v = stats.maxwell.fit(v6101) #finding mean and variance 
pdf_6101 = stats.maxwell.cdf(ln6101, scale = 2.77) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6101['Mass1'],x6101['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6101['Mass2'],y6101['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6101,v_6101, '*',c='blue',label='NGC6101',zorder=3)
plt.axhline(y=10.5,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6101',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6101, pdf_6101,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6101,histtype='step',normed=True,cumulative=True, bins=12, color='blue',linewidth=1.5,label='NGC6101')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6101['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6101['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6101,cumulative=True,histtype='step', normed=1, bins=12, color = 'blue',linewidth=1.5,label = 'NGC6101')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)', fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,23)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6101['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6101['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6101,cumulative=True,histtype='step', normed=1, bins=8,linewidth=1.5, color = 'blue',label = 'NGC6101')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6101.png')

# %%
ln6121 = np.linspace(min(v6121), max(v6121), len(v6121))
mean6121, v = stats.maxwell.fit(v6121) #finding mean and variance 
pdf_6121 = stats.maxwell.cdf(ln6121, scale = 4) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6121['Mass1'],x6121['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6121['Mass2'],y6121['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6121,v_6121, '*',c='blue',label='NGC6121',zorder=3)
plt.axhline(y=20.3,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6121',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6121, pdf_6121,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6121,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6121')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6121['Velocity1'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color='black',label='1+2')
plt.hist(y6121['Velocity2'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6121,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6121')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,23)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6121['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6121['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6121,cumulative=True,histtype='step', normed=1, bins=9,linewidth=1.5, color = 'blue',label = 'NGC6121')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')

fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6121.png')

# %%
ln6171 = np.linspace(min(v6171), max(v6171), len(v6171))
mean6171, v = stats.maxwell.fit(v6171) #finding mean and variance 
pdf_6171 = stats.maxwell.cdf(ln6171, scale = 4.1) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6171['Mass1'],x6171['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6171['Mass2'],y6171['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6171,v_6171, '*',c='blue',label='NGC6171',zorder=3)
plt.axhline(y=16.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6171',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6171, pdf_6171,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6171,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6171')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6171['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6171['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6171,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6171')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Cases (%)',fontsize = 'x-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,13)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6171['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6171['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6121,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6121')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
plt.xlim(0.9,1.2)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6171.png')

# %%
ln6218 = np.linspace(min(v6218), max(v6218), len(v6218))
mean6218, v = stats.maxwell.fit(v6218) #finding mean and variance 
pdf_6218 = stats.maxwell.cdf(ln6218, scale = 4.5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6218['Mass1'],x6218['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6218['Mass2'],y6218['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6218,v_6218, '*',c='blue',label='NGC6218',zorder=3)
plt.axhline(y=19.6,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6218',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6218, pdf_6218,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6218,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6218')
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6218['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6218['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6218,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6218')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,14)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6218['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6218['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6218,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6218')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6218.png')

# %%
ln6254 = np.linspace(min(v6254), max(v6254), len(v6254))
mean6254, v = stats.maxwell.fit(v6254) #finding mean and variance 
pdf_6254 = stats.maxwell.cdf(ln6254, scale = 6.6) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6254['Mass1'],x6254['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6254['Mass2'],y6254['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6254,v_6254, '*',c='blue',label='NGC6254',zorder=3)
plt.axhline(y=21.6,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6254',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6254, pdf_6254,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6254,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6254')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6254['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6254['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6254,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6254')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,14)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6254['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6254['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6254,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6254')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6254.png')

# %%
ln6304 = np.linspace(min(v6304), max(v6304), len(v6304))
mean6304, v = stats.maxwell.fit(v6304) #finding mean and variance 
pdf_6304 = stats.maxwell.cdf(ln6304, scale = 6.15) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6304['Mass1'],x6304['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6304['Mass2'],y6304['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6304,v_6304, '*',c='blue',label='NGC6304',zorder=3)
plt.axhline(y=25.2,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6304',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6304, pdf_6304,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6304,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6304')
plt.xlim(0,14)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6304['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6304['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6304,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6304')
plt.xlim(0,14)
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')

plt.subplot2grid((3,3), (2,2))
plt.hist(x6304['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6304['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6304,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6304')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6304.png')

# %%
ln6341 = np.linspace(min(v6341), max(v6341), len(v6341))
mean6341, v = stats.maxwell.fit(v6341) #finding mean and variance 
pdf_6341 = stats.maxwell.cdf(ln6341, scale = 6) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6341['Mass1'],x6341['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6341['Mass2'],y6341['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6341,v_6341, '*',c='blue',label='NGC6341',zorder=3)
plt.axhline(y=33.1,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6341',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6341, pdf_6341,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6341,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6341')
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6341['Velocity1'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color='black',label='1+2')
plt.hist(y6341['Velocity2'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6341,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6341')
plt.xlim(0,28)
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')

plt.subplot2grid((3,3), (2,2))
plt.hist(x6341['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6341['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6341,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6341')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6341.png')

# %%
ln6352 = np.linspace(min(v6352), max(v6352), len(v6352))
mean6352, v = stats.maxwell.fit(v6352) #finding mean and variance 
pdf_6352 = stats.maxwell.cdf(ln6352, scale = 3.19) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6352['Mass1'],x6352['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6352['Mass2'],y6352['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6352,v_6352, '*',c='blue',label='NGC6352',zorder=3)
plt.axhline(y=12.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6352',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6352, pdf_6352,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6352,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6352')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6352['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6352['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6352,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6352')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,12)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6352['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6352['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6352,cumulative=True,histtype='step', normed=1, bins=8,linewidth=1.5, color = 'blue',label = 'NGC6352')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6352.png')

# %%
ln6362 = np.linspace(min(v6362), max(v6362), len(v6362))
mean6362, v = stats.maxwell.fit(v6362) #finding mean and variance 
pdf_6362 = stats.maxwell.cdf(ln6362, scale = 2.8) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6362['Mass1'],x6362['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6362['Mass2'],y6362['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6362,v_6362, '*',c='blue',label='NGC6362',zorder=3)
plt.axhline(y=14.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6362',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6362, pdf_6362,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6362,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6362')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6362['Velocity1'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color='black',label='1+2')
plt.hist(y6362['Velocity2'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6362,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6362')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,10)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6362['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6362['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6362,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6362')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6362.png')

# %%
ln6366 = np.linspace(min(v6366), max(v6366), len(v6366))
mean6366, v = stats.maxwell.fit(v6366) #finding mean and variance 
pdf_6366 = stats.maxwell.cdf(ln6366, scale = 2.8) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6366['Mass1'],x6366['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6366['Mass2'],y6366['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6366,v_6366, '*',c='blue',label='NGC6366',zorder=3)
plt.axhline(y=14.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6366',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6366, pdf_6366,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6366,histtype='step',normed=True,cumulative=True, bins=5, color='blue',linewidth=1.5,label='NGC6366')
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6366['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6366['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6366,cumulative=True,histtype='step', normed=1, bins=5, color = 'blue',linewidth=1.5,label = 'NGC6366')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,6.5)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6366['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6366['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6366,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6366')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6366.png')

# %%
ln6388 = np.linspace(min(v6388), max(v6388), len(v6388))
mean6388, v = stats.maxwell.fit(v6388) #finding mean and variance 
pdf_6388 = stats.maxwell.cdf(ln6388, scale = 18.9) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6388['Mass1'],x6388['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6388['Mass2'],y6388['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6388,v_6388, '*',c='blue',label='NGC6388',zorder=3)
plt.axhline(y=78.2,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6388',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6388, pdf_6388,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6388,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6388')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6388['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6388['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6388,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6388')
plt.xlim(0,75)
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')

plt.subplot2grid((3,3), (2,2))
plt.hist(x6388['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6388['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6388,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6388')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6388.png')

# %%
ln6541 = np.linspace(min(v6541), max(v6541), len(v6541))
mean6541, v = stats.maxwell.fit(v6541) #finding mean and variance 
pdf_6541 = stats.maxwell.cdf(ln6541, scale = 8.2) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6541['Mass1'],x6541['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6541['Mass2'],y6541['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6541,v_6541, '*',c='blue',label='NGC6541',zorder=3)
plt.axhline(y=35.8,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6541',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6541, pdf_6541,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6541,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6541')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6541['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6541['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6541,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6541')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,35)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6541['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6541['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6541,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6541')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6541.png')

# %%
ln6584 = np.linspace(min(v6584), max(v6584), len(v6584))
mean6584, v = stats.maxwell.fit(v6584) #finding mean and variance 
pdf_6584 = stats.maxwell.cdf(ln6584, scale = 5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6584['Mass1'],x6584['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6584['Mass2'],y6584['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6584,v_6584, '*',c='blue',label='NGC6584',zorder=3)
plt.axhline(y=19.2,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6584',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6584, pdf_6584,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6584,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6584')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6584['Velocity1'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color='black',label='1+2')
plt.hist(y6584['Velocity2'],cumulative=True,histtype='step', normed=1, bins=50,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6584,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6584')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,17)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6584['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6584['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6584,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6584')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6584.png')

# %%
ln6624 = np.linspace(min(v6624), max(v6624), len(v6624))
mean6624, v = stats.maxwell.fit(v6624) #finding mean and variance 
pdf_6624 = stats.maxwell.cdf(ln6624, scale = 5.4) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6624['Mass1'],x6624['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6624['Mass2'],y6624['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6624,v_6624, '*',c='blue',label='NGC6624',zorder=3)
plt.axhline(y=31.5,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6624',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6624, pdf_6624,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6624,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6624')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6624['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6624['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6624,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6624')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,28)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6624['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6624['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6624,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6624')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6624.png')

# %%
ln6637 = np.linspace(min(v6637), max(v6637), len(v6637))
mean6637, v = stats.maxwell.fit(v6637) #finding mean and variance 
pdf_6637 = stats.maxwell.cdf(ln6637, scale = 7.31) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6637['Mass1'],x6637['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6637['Mass2'],y6637['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6637,v_6637, '*',c='blue',label='NGC6637',zorder=3)
plt.axhline(y=28.9,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6637',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6637, pdf_6637,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6637,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6637')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6637['Velocity1'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color='black',label='1+2')
plt.hist(y6637['Velocity2'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6637,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6637')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,20)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6637['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6637['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6637,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6637')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6637.png')

# %%
ln6652 = np.linspace(min(v6652), max(v6652), len(v6652))
mean6652, v = stats.maxwell.fit(v6652) #finding mean and variance 
pdf_6652 = stats.maxwell.cdf(ln6652, scale = 5.86) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6652['Mass1'],x6652['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6652['Mass2'],y6652['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6652,v_6652, '*',c='blue',label='NGC6652',zorder=3)
plt.axhline(y=23.7,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6652',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6652, pdf_6652,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6652,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6652')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6652['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6652['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6652,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6652')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,15)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6652['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6652['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6652,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6652')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6652.png')

# %%
ln6656 = np.linspace(min(v6656), max(v6656), len(v6656))
mean6656, v = stats.maxwell.fit(v6656) #finding mean and variance 
pdf_6656 = stats.maxwell.cdf(ln6656, scale = 7.8) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6656['Mass1'],x6656['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6656['Mass2'],y6656['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6656,v_6656, '*',c='blue',label='NGC6656',zorder=3)
plt.axhline(y=33,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6656',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6656, pdf_6656,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6656,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6681')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6656['Velocity1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6656['Velocity2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6656,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6681')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,20)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6656['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6656['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6656,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6681')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6656.png')

# %%
ln6681 = np.linspace(min(v6681), max(v6681), len(v6681))
mean6681, v = stats.maxwell.fit(v6681) #finding mean and variance 
pdf_6681 = stats.maxwell.cdf(ln6681, scale = 5.2) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6681['Mass1'],x6681['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6681['Mass2'],y6681['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6681,v_6681, '*',c='blue',label='NGC6681',zorder=3)
plt.axhline(y=22.4,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6681',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6681, pdf_6681,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6681,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6681')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6681['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6681['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6681,cumulative=True,histtype='step', normed=1, bins=8, color = 'blue',linewidth=1.5,label = 'NGC6681')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,18)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6681['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6681['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6681,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6681')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6681.png')

# %%
ln6717 = np.linspace(min(v6717), max(v6717), len(v6717))
mean6717, v = stats.maxwell.fit(v6717) #finding mean and variance 
pdf_6717 = stats.maxwell.cdf(ln6717, scale = 3.72) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6717['Mass1'],x6717['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6717['Mass2'],y6717['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6717,v_6717, '*',c='blue',label='NGC6717',zorder=3)
plt.axhline(y=16.8,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6717',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6717, pdf_6717,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6717,histtype='step',normed=True,cumulative=True, bins=10, color='blue',linewidth=1.5,label='NGC6717')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6717['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6717['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6717,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6717')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,11)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6717['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6717['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6717,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6717')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6717.png')

# %%
ln6723 = np.linspace(min(v6723), max(v6723), len(v6723))
mean6723, v = stats.maxwell.fit(v6723) #finding mean and variance 
pdf_6723 = stats.maxwell.cdf(ln6723, scale = 5.69) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6723['Mass1'],x6723['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6723['Mass2'],y6723['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6723,v_6723, '*',c='blue',label='NGC6723',zorder=3)
plt.axhline(y=20.7,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6723',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6723, pdf_6723,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6723,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6723')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6723['Velocity1'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color='black',label='1+2')
plt.hist(y6723['Velocity2'],cumulative=True,histtype='step', normed=1, bins=45,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6723,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6723')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,20)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6723['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6723['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6723,cumulative=True,histtype='step', normed=1, bins=8,linewidth=1.5, color = 'blue',label = 'NGC6723')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6723.png')

# %%
ln6809 = np.linspace(min(v6809), max(v6809), len(v6809))
mean6809, v = stats.maxwell.fit(v6809) #finding mean and variance 
pdf_6809 = stats.maxwell.cdf(ln6809, scale = 4) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6809['Mass1'],x6809['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6809['Mass2'],y6809['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6809,v_6809, '*',c='blue',label='NGC6809',zorder=3)
plt.axhline(y=15.3,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6809',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6809, pdf_6809,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6809,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6809')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6809['Velocity1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y6809['Velocity2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6809,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC6809')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,16)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6809['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6809['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6809,cumulative=True,histtype='step', normed=1, bins=15,linewidth=1.5, color = 'blue',label = 'NGC6809')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6809.png')

# %%
ln6838 = np.linspace(min(v6838), max(v6838), len(v6838))
mean6838, v = stats.maxwell.fit(v6838) #finding mean and variance 
pdf_6838 = stats.maxwell.cdf(ln6838, scale = 2.3) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x6838['Mass1'],x6838['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y6838['Mass2'],y6838['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_6838,v_6838, '*',c='blue',label='NGC6838',zorder=3)
plt.axhline(y=12.1,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 6366',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln6838, pdf_6838,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v6838,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC6838')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x6838['Velocity1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y6838['Velocity2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v6838,cumulative=True,histtype='step', normed=1, bins=18, color = 'blue',linewidth=1.5,label = 'NGC6838')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,15)

plt.subplot2grid((3,3), (2,2))
plt.hist(x6838['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y6838['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m6838,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC6838')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC6838.png')

# %%
ln7089 = np.linspace(min(v7089), max(v7089), len(v7089))
mean7089, v = stats.maxwell.fit(v7089) #finding mean and variance 
pdf_7089 = stats.maxwell.cdf(ln7089, scale = 8.2) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x7089['Mass1'],x7089['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y7089['Mass2'],y7089['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_7089,v_7089, '*',c='blue',label='NGC7089',zorder=3)
plt.axhline(y=37.1,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 7089',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln7089, pdf_7089,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v7089,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC7089')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x7089['Velocity1'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color='black',label='1+2')
plt.hist(y7089['Velocity2'],cumulative=True,histtype='step', normed=1, bins=40,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v7089,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC7089')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,27)

plt.subplot2grid((3,3), (2,2))
plt.hist(x7089['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y7089['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m7089,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC7089')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC7089.png')

# %%
ln7099 = np.linspace(min(v7099), max(v7099), len(v7099))
mean7099, v = stats.maxwell.fit(v7099) #finding mean and variance 
pdf_7099 = stats.maxwell.cdf(ln7099, scale = 5.5) 

fig = plt.figure(1)
gridspec.GridSpec(3,3)

plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.plot(x7099['Mass1'],x7099['Velocity1'], 'o' ,c='black',label='1+2',zorder=1)
plt.plot(y7099['Mass2'],y7099['Velocity2'], 'o',c='gray',mfc="None", label='2+2',zorder=2)
plt.plot(m_7099,v_7099, '*',c='blue',label='NGC7099',zorder=3)
plt.axhline(y=23.8,xmin=0,xmax=3,c="red",linestyle='--',linewidth=2.0,label='Escape Velocity',zorder=4)
plt.title('NGC 7099',fontsize = 'x-large')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'x-large')
plt.ylabel('Log Velocity(km/s)',fontsize = 'x-large')
plt.yscale('log')
plt.legend(loc="lower right", fontsize = 'small')

plt.subplot2grid((3,3), (0,2,))
plt.plot(ln7099, pdf_7099,color='green',linewidth=2.0,label='Maxwell')
plt.hist(v7099,histtype='step',normed=True,cumulative=True, bins=8, color='blue',linewidth=1.5,label='NGC7099')
#plt.xlim(0,13)
plt.xlabel('Velocity(km/s)')
plt.title('Maxwellian Velocity Distribution',fontsize = 'medium')
plt.legend(loc="lower right",fontsize = 'small')

plt.subplot2grid((3,3), (1,2))
plt.hist(x7099['Velocity1'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color='black',label='1+2')
plt.hist(y7099['Velocity2'],cumulative=True,histtype='step', normed=1, bins=35,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(v7099,cumulative=True,histtype='step', normed=1, bins=10, color = 'blue',linewidth=1.5,label = 'NGC7099')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Velocity(km/s)',fontsize = 'medium')
plt.ylabel('Frequency (%)',fontsize = 'xx-large')
plt.title('Collision Model (Velocity)',fontsize = 'medium')
plt.xlim(0,20)

plt.subplot2grid((3,3), (2,2))
plt.hist(x7099['Mass1'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color='black',label='1+2')
plt.hist(y7099['Mass2'],cumulative=True,histtype='step', normed=1, bins=30,linewidth=1.5, color = 'gray',label = '2+2')
plt.hist(m7099,cumulative=True,histtype='step', normed=1, bins=10,linewidth=1.5, color = 'blue',label = 'NGC7099')
plt.legend(loc="lower right",fontsize = 'small')
plt.xlabel('Mass ($M_{\odot}$)',fontsize = 'medium')
plt.title('Collision Model (Mass)',fontsize = 'medium')
#plt.xlim(0.70,1.3)


fig.set_size_inches(w=11,h=7)
fig.tight_layout()
fig.savefig('NGC7099.png')
