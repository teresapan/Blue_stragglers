# %%
from astropy.io import ascii
import matplotlib.pyplot as plt
from __future__ import division
import numpy as np
import pandas as pd
import scipy as scipy
# %matplotlib inline

# %%
#Reading the data
data_1851 = ascii.read("BSS_velocity_mass_1851.txt")
data_3201 = ascii.read("BSS_velocity_mass_3201.txt")
data_4590 = ascii.read("BSS_velocity_mass_4590.txt")
data_4833 = ascii.read("BSS_velocity_mass_4833.txt")
data_5286 = ascii.read("BSS_velocity_mass_5286.txt")
data_5927 = ascii.read("BSS_velocity_mass_5927.txt")
data_6101 = ascii.read("BSS_velocity_mass_6101.txt")
data_6121 = ascii.read("BSS_velocity_mass_6121.txt")
data_6171 = ascii.read("BSS_velocity_mass_6171.txt")
data_6218 = ascii.read("BSS_velocity_mass_6218.txt")
data_6254 = ascii.read("BSS_velocity_mass_6254.txt")
data_6304 = ascii.read("BSS_velocity_mass_6304.txt")
data_6341 = ascii.read("BSS_velocity_mass_6341.txt")
data_6352 = ascii.read("BSS_velocity_mass_6352.txt")
data_6362 = ascii.read("BSS_velocity_mass_6362.txt")
data_6366 = ascii.read("BSS_velocity_mass_6366.txt")
data_6388 = ascii.read("BSS_velocity_mass_6388.txt")
data_6541 = ascii.read("BSS_velocity_mass_6541.txt")
data_6584 = ascii.read("BSS_velocity_mass_6584.txt")
data_6624 = ascii.read("BSS_velocity_mass_6624.txt")
data_6637 = ascii.read("BSS_velocity_mass_6637.txt")
data_6652 = ascii.read("BSS_velocity_mass_6652.txt")
data_6656 = ascii.read("BSS_velocity_mass_6656.txt")
data_6681 = ascii.read("BSS_velocity_mass_6681.txt")
data_6717 = ascii.read("BSS_velocity_mass_6717.txt")
data_6723 = ascii.read("BSS_velocity_mass_6723.txt")
data_6809 = ascii.read("BSS_velocity_mass_6809.txt")
data_6838 = ascii.read("BSS_velocity_mass_3201.txt")
data_7089 = ascii.read("BSS_velocity_mass_7089.txt")
data_7099 = ascii.read("BSS_velocity_mass_7099.txt")

# %%
#Making them into arrays

v_1851 = np.asarray(data_1851['velocity(km/s)'])
m_1851 = np.asarray(data_1851['mass(Msun)'])

v_3201 = np.asarray(data_3201['velocity(km/s)'])
m_3201 = np.asarray(data_3201['mass(Msun)'])

v_4590 = np.asarray(data_4590['col1'])
m_4590 = np.asarray(data_4590['col2'])

v_4833 = np.asarray(data_4833['col1'])
m_4833 = np.asarray(data_4833['col2'])

v_5286 = np.asarray(data_5286['col1'])
m_5286 = np.asarray(data_5286['col2'])

v_5927 = np.asarray(data_5927['col1'])
m_5927 = np.asarray(data_5927['col2'])

v_6101 = np.asarray(data_6101['col1'])
m_6101 = np.asarray(data_6101['col2'])

v_6121 = np.asarray(data_6121['col1'])
m_6121 = np.asarray(data_6121['col2'])

v_6171 = np.asarray(data_6171['col1'])
m_6171 = np.asarray(data_6171['col2'])

v_6218 = np.asarray(data_6218['col1'])
m_6218 = np.asarray(data_6218['col2'])

v_6254 = np.asarray(data_6254['col1'])
m_6254 = np.asarray(data_6254['col2'])

v_6304 = np.asarray(data_6304['col1'])
m_6304 = np.asarray(data_6304['col2'])

v_6341 = np.asarray(data_6341['col1'])
m_6341 = np.asarray(data_6341['col2'])

v_6352 = np.asarray(data_6352['col1'])
m_6352 = np.asarray(data_6352['col2'])

v_6362 = np.asarray(data_6362['col1'])
m_6362 = np.asarray(data_6362['col2'])

v_6366 = np.asarray(data_6366['col1'])
m_6366 = np.asarray(data_6366['col2'])

v_6388 = np.asarray(data_6388['col1'])
m_6388 = np.asarray(data_6388['col2'])

v_6541 = np.asarray(data_6541['col1'])
m_6541 = np.asarray(data_6541['col2'])

v_6584 = np.asarray(data_6584['col1'])
m_6584 = np.asarray(data_6584['col2'])

v_6624 = np.asarray(data_6624['col1'])
m_6624 = np.asarray(data_6624['col2'])

v_6637 = np.asarray(data_6637['col1'])
m_6637 = np.asarray(data_6637['col2'])

v_6652 = np.asarray(data_6652['col1'])
m_6652 = np.asarray(data_6652['col2'])

v_6656 = np.asarray(data_6656['col1'])
m_6656 = np.asarray(data_6656['col2'])

v_6681 = np.asarray(data_6681['col1'])
m_6681 = np.asarray(data_6681['col2'])

v_6717 = np.asarray(data_6717['col1'])
m_6717 = np.asarray(data_6717['col2'])

v_6723 = np.asarray(data_6723['col1'])
m_6723 = np.asarray(data_6723['col2'])

v_6809 = np.asarray(data_6809['col1'])
m_6809 = np.asarray(data_6809['col2'])

v_6838 = np.asarray(data_6838['velocity(km/s)'])
m_6838 = np.asarray(data_6838['mass(Msun)'])

v_7089 = np.asarray(data_7089['col1'])
m_7089 = np.asarray(data_7089['col2'])

v_7099 = np.asarray(data_7099['col1'])
m_7099 = np.asarray(data_7099['col2'])

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
ax1.plot(m_1851,v_1851,'o')
ax1.set_title('NGC 4833')
ax1.set_xlabel('Mass(Msun)')
ax1.set_ylabel('Velocity(km/s)')

ax2.plot(m_3201,v_3201,'o')
ax2.set_title('NGC 3201')
ax2.set_xlabel('Mass(Msun)')
ax2.set_ylabel('Velocity(km/s)')

ax3.plot(m_4590,v_4590,'o')
ax3.set_title('NGC 4590')
ax3.set_xlabel('Mass(Msun)')
ax3.set_ylabel('Velocity(km/s)')

ax4.plot(m_4833,v_4833,'o')
ax4.set_title('NGC 4833')
ax4.set_xlabel('Mass(Msun)')
ax4.set_ylabel('Velocity(km/s)')


fig = plt.gcf()
fig.set_size_inches(11,11, forward = True)

# %%
#Use pandas to read theoretical data

data = pd.read_csv('mb_NGC1261_ecnum1.txt',sep=" ")

# %%
df = pd.DataFrame(data)

# %%
df.loc[:,['Unnamed: 1', '#Mcl[MSun]']] = df[['#Mcl[MSun]', 'Unnamed: 1']].values

df[['A', 'B']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-71965d1bda6c> in <module>()
# ----> 1 df.loc[:,['Unnamed: 1', '#Mcl[MSun]']] = df[['#Mcl[MSun]', 'Unnamed: 1']].values
#       2
#       3 df[['A', 'B']]
#
# TypeError: list indices must be integers, not list

# %%
v = np.asarray(data['#Mcl[MSun]'])
m = np.asarray(data['Unnamed: 1'])

# %%
data
# Out:
#          #Mcl[MSun]    Unnamed: 1    Unnamed: 2  <m[MSun]>  Unnamed: 4  \
# 0      2.239140E+05  3.000000E-01  9.695709E-01       5.17     20.3689
# 1      #Mcoll[MSun]   vcoll[km/s]         ctype        NaN         NaN
# 2      1.098294E+00  1.502213E+01           NaN        NaN      5.0000
# 3      4.537207E-01  6.723907E+00           NaN        NaN      4.0000
# 4      1.099723E+00  6.438911E+00           NaN        NaN      4.0000
# 5      1.156322E+00  8.768518E+00           NaN        NaN      4.0000
# 6      1.114116E+00  1.380368E+01           NaN        NaN      6.0000
# 7      7.973882E-01  6.497905E+00           NaN        NaN      4.0000
# 8      8.422563E-01  3.769612E+00           NaN        NaN      4.0000
# 9      1.108919E+00  1.240610E+01           NaN        NaN      6.0000
# 10     1.232724E+00  1.199249E+01           NaN        NaN      6.0000
# 11     8.044852E-01  4.286909E+00           NaN        NaN      6.0000
# 12     1.076121E+00  1.168156E+01           NaN        NaN      4.0000
# 13     7.005215E-01  1.561269E+01           NaN        NaN      4.0000
# 14     1.173831E+00  2.014539E+00           NaN        NaN      6.0000
# 15     1.163149E+00  7.189604E+00           NaN        NaN      6.0000
# 16     1.685872E+00  6.955474E+00           NaN        NaN      6.0000
# 17     1.120052E+00  4.690789E+00           NaN        NaN      4.0000
# 18     6.070574E-01  9.064836E+00           NaN        NaN      4.0000
# 19     1.581361E+00  6.439914E+00           NaN        NaN      4.0000
# 20     5.416998E-01  6.731376E+00           NaN        NaN      6.0000
# 21     7.015293E-01  2.468565E+00           NaN        NaN      4.0000
# 22     7.726886E-01  3.293052E+00           NaN        NaN      4.0000
# 23     8.219014E-01  1.544834E+01           NaN        NaN      5.0000
# 24     2.845065E-01  7.820093E+00           NaN        NaN      4.0000
# 25     1.405683E+00  5.273777E+00           NaN        NaN      6.0000
# 26     7.384672E-01  3.462387E+00           NaN        NaN      4.0000
# 27     7.878477E-01  1.880704E+00           NaN        NaN      4.0000
# 28     8.362276E-01  1.144641E+01           NaN        NaN      6.0000
# 29     2.038860E-01  6.845554E+00           NaN        NaN      4.0000
# ...             ...           ...           ...        ...         ...
# 35731  1.153004E+00  7.527742E+00           NaN        NaN      4.0000
# 35732  8.817036E-01  7.953635E+00           NaN        NaN      4.0000
# 35733  1.974884E+00  2.304546E+00           NaN        NaN      6.0000
# 35734  1.130767E+00  9.364015E+00           NaN        NaN      4.0000
# 35735  1.073220E+00  6.074036E+00           NaN        NaN      4.0000
# 35736  1.124803E+00  7.844182E+00           NaN        NaN      6.0000
# 35737  7.683324E-01  5.548877E+00           NaN        NaN      4.0000
# 35738  2.812129E-01  1.545073E+01           NaN        NaN      4.0000
# 35739  1.382312E+00  3.737142E+00           NaN        NaN      6.0000
# 35740  7.649705E-01  1.341835E+01           NaN        NaN      6.0000
# 35741  6.641333E-01  5.238351E+00           NaN        NaN      6.0000
# 35742  5.573197E-01  7.978005E+00           NaN        NaN      4.0000
# 35743  1.439719E+00  4.356528E+00           NaN        NaN      6.0000
# 35744  4.935315E-01  1.438173E+01           NaN        NaN      4.0000
# 35745  9.047896E-01  6.455520E+00           NaN        NaN      6.0000
# 35746  4.731190E-01  3.857479E+00           NaN        NaN      4.0000
# 35747  9.811577E-01  4.368236E+00           NaN        NaN      6.0000
# 35748  7.064304E-01  6.808725E+00           NaN        NaN      4.0000
# 35749  1.371612E+00  6.037752E+00           NaN        NaN      4.0000
# 35750  1.061097E+00  1.814479E+00           NaN        NaN      4.0000
# 35751  8.189759E-01  6.032212E+00           NaN        NaN      6.0000
# 35752  1.175049E+00  9.026993E+00           NaN        NaN      4.0000
# 35753  1.140191E+00  9.192559E+00           NaN        NaN      4.0000
# 35754  3.456618E-01  1.754328E+01           NaN        NaN      4.0000
# 35755  1.714866E+00  4.644314E+00           NaN        NaN      6.0000
# 35756  1.001192E+00  1.817555E+00           NaN        NaN      6.0000
# 35757  7.970158E-01  9.653907E+00           NaN        NaN      6.0000
# 35758  9.094037E-01  4.250906E+00           NaN        NaN      6.0000
# 35759  8.850001E-01  7.224462E+00           NaN        NaN      4.0000
# 35760  1.099862E+00  1.012978E+00           NaN        NaN      4.0000
#
#        Unnamed: 5  Unnamed: 6  MSTO[MSun]  Unnamed: 8  Unnamed: 9  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# 5             NaN         NaN         NaN         NaN         NaN
# 6             NaN         NaN         NaN         NaN         NaN
# 7             NaN         NaN         NaN         NaN         NaN
# 8             NaN         NaN         NaN         NaN         NaN
# 9             NaN         NaN         NaN         NaN         NaN
# 10            NaN         NaN         NaN         NaN         NaN
# 11            NaN         NaN         NaN         NaN         NaN
# 12            NaN         NaN         NaN         NaN         NaN
# 13            NaN         NaN         NaN         NaN         NaN
# 14            NaN         NaN         NaN         NaN         NaN
# 15            NaN         NaN         NaN         NaN         NaN
# 16            NaN         NaN         NaN         NaN         NaN
# 17            NaN         NaN         NaN         NaN         NaN
# 18            NaN         NaN         NaN         NaN         NaN
# 19            NaN         NaN         NaN         NaN         NaN
# 20            NaN         NaN         NaN         NaN         NaN
# 21            NaN         NaN         NaN         NaN         NaN
# 22            NaN         NaN         NaN         NaN         NaN
# 23            NaN         NaN         NaN         NaN         NaN
# 24            NaN         NaN         NaN         NaN         NaN
# 25            NaN         NaN         NaN         NaN         NaN
# 26            NaN         NaN         NaN         NaN         NaN
# 27            NaN         NaN         NaN         NaN         NaN
# 28            NaN         NaN         NaN         NaN         NaN
# 29            NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 35731         NaN         NaN         NaN         NaN         NaN
# 35732         NaN         NaN         NaN         NaN         NaN
# 35733         NaN         NaN         NaN         NaN         NaN
# 35734         NaN         NaN         NaN         NaN         NaN
# 35735         NaN         NaN         NaN         NaN         NaN
# 35736         NaN         NaN         NaN         NaN         NaN
# 35737         NaN         NaN         NaN         NaN         NaN
# 35738         NaN         NaN         NaN         NaN         NaN
# 35739         NaN         NaN         NaN         NaN         NaN
# 35740         NaN         NaN         NaN         NaN         NaN
# 35741         NaN         NaN         NaN         NaN         NaN
# 35742         NaN         NaN         NaN         NaN         NaN
# 35743         NaN         NaN         NaN         NaN         NaN
# 35744         NaN         NaN         NaN         NaN         NaN
# 35745         NaN         NaN         NaN         NaN         NaN
# 35746         NaN         NaN         NaN         NaN         NaN
# 35747         NaN         NaN         NaN         NaN         NaN
# 35748         NaN         NaN         NaN         NaN         NaN
# 35749         NaN         NaN         NaN         NaN         NaN
# 35750         NaN         NaN         NaN         NaN         NaN
# 35751         NaN         NaN         NaN         NaN         NaN
# 35752         NaN         NaN         NaN         NaN         NaN
# 35753         NaN         NaN         NaN         NaN         NaN
# 35754         NaN         NaN         NaN         NaN         NaN
# 35755         NaN         NaN         NaN         NaN         NaN
# 35756         NaN         NaN         NaN         NaN         NaN
# 35757         NaN         NaN         NaN         NaN         NaN
# 35758         NaN         NaN         NaN         NaN         NaN
# 35759         NaN         NaN         NaN         NaN         NaN
# 35760         NaN         NaN         NaN         NaN         NaN
#
#        sigma0[km/s]  vesc[kms/s]
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# 5               NaN          NaN
# 6               NaN          NaN
# 7               NaN          NaN
# 8               NaN          NaN
# 9               NaN          NaN
# 10              NaN          NaN
# 11              NaN          NaN
# 12              NaN          NaN
# 13              NaN          NaN
# 14              NaN          NaN
# 15              NaN          NaN
# 16              NaN          NaN
# 17              NaN          NaN
# 18              NaN          NaN
# 19              NaN          NaN
# 20              NaN          NaN
# 21              NaN          NaN
# 22              NaN          NaN
# 23              NaN          NaN
# 24              NaN          NaN
# 25              NaN          NaN
# 26              NaN          NaN
# 27              NaN          NaN
# 28              NaN          NaN
# 29              NaN          NaN
# ...             ...          ...
# 35731           NaN          NaN
# 35732           NaN          NaN
# 35733           NaN          NaN
# 35734           NaN          NaN
# 35735           NaN          NaN
# 35736           NaN          NaN
# 35737           NaN          NaN
# 35738           NaN          NaN
# 35739           NaN          NaN
# 35740           NaN          NaN
# 35741           NaN          NaN
# 35742           NaN          NaN
# 35743           NaN          NaN
# 35744           NaN          NaN
# 35745           NaN          NaN
# 35746           NaN          NaN
# 35747           NaN          NaN
# 35748           NaN          NaN
# 35749           NaN          NaN
# 35750           NaN          NaN
# 35751           NaN          NaN
# 35752           NaN          NaN
# 35753           NaN          NaN
# 35754           NaN          NaN
# 35755           NaN          NaN
# 35756           NaN          NaN
# 35757           NaN          NaN
# 35758           NaN          NaN
# 35759           NaN          NaN
# 35760           NaN          NaN
#
# [35761 rows x 12 columns]

# %%
df[:3]
# Out:
# [['#Mcl[MSun]', 'Unnamed: 1']]
